# %% [markdown]
# # Find and save the NRMSE for each canton

# %%
import pandas as pd
import sys
import numpy as np
from sklearn.metrics import root_mean_squared_error
import joblib
from pathlib import Path

project_root = Path.cwd().parent
sys.path.insert(0, str(project_root))

from model_rr import Model

# %%
cantons = [101, 102, 103, 104, 105, 106, 107, 108, 109, 110, 111, 112, 113, 114, 115, 116, 117, 118, 119, 120, 201, -202, 203, 204, 205, 206, 207, 208, 209, 210, 211, 212, 213, 214, 215, 216, 301, 302, 303, 304, 305, 306, 307, 308, 401, 402, 403, 404, 405, 406, 407, 408, 409, 410, 501, 502, 503, 504, 505, 506, 507, 508, 509, 510, 511, 601, 602, 603, 604, 605, 606, 607, 608, 609, 610, 611, 701, 702, 703, 704, 705, 706]

cantons = [str(x) for x in cantons]

# %%
df = pd.read_csv('/home/marianne.pena/mainMarianne/dengue-model/data/full_data.csv')

# %%
df_nrmse = pd.read_csv(f"/home/marianne.pena/mainMarianne/dengue-model/data/confints/xgb_confint_test_full.csv")

# %% [markdown]
# ## Best

# %%
best_cantons = df_nrmse.nsmallest(3, "nrmse").iloc[:, 0].tolist()

# %%
best_1 = Model(df, str(best_cantons[0]))

X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = best_1.partition()

y_pred_point, lower_bound, upper_bound = best_1.prediction_intervals_aci("xgb", X_combined, y_combined, X_test, y_test, epsilon, alpha=0.05, gamma=0.005, n_resamplings=100, full = True)

best_1.serie_temp_canton("xgb", y_pred_point, lower_bound, upper_bound, lims = [0, 35])
# Out:
# Elapsed time: 5.75 seconds

# %%
best_2 = Model(df, str(best_cantons[1]))

X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = best_2.partition()

y_pred_point, lower_bound, upper_bound = best_2.prediction_intervals_aci("xgb", X_combined, y_combined, X_test, y_test, epsilon, alpha=0.05, gamma=0.005, n_resamplings=100, full = True)

best_2.serie_temp_canton("xgb", y_pred_point, lower_bound, upper_bound, lims = [0, 35])
# Out:
# Elapsed time: 6.05 seconds

# %%
best_3 = Model(df, str(best_cantons[2]))

X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = best_3.partition()

y_pred_point, lower_bound, upper_bound = best_3.prediction_intervals_aci("xgb", X_combined, y_combined, X_test, y_test, epsilon, alpha=0.05, gamma=0.005, n_resamplings=100, full = True)

best_3.serie_temp_canton("xgb", y_pred_point, lower_bound, upper_bound, lims = [0, 35])
# Out:
# Elapsed time: 6.01 seconds

# %% [markdown]
# # Worst

# %%
worst_cantons = df_nrmse.nlargest(3, "nrmse").iloc[:, 0].tolist()

# %%
worst_1 = Model(df, str(worst_cantons[0]))

X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = worst_1.partition()

y_pred_point, lower_bound, upper_bound = worst_1.prediction_intervals_aci("xgb", X_combined, y_combined, X_test, y_test, epsilon, alpha=0.05, gamma=0.005, n_resamplings=100, full = True)

worst_1.serie_temp_canton("xgb", y_pred_point, lower_bound, upper_bound, lims = [0, 35])
# Out:
# Elapsed time: 6.08 seconds

# %%
worst_2 = Model(df, str(worst_cantons[1]))

X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = worst_2.partition()

y_pred_point, lower_bound, upper_bound = worst_2.prediction_intervals_aci("xgb", X_combined, y_combined, X_test, y_test, epsilon, alpha=0.05, gamma=0.005, n_resamplings=100, full = True)

worst_2.serie_temp_canton("xgb", y_pred_point, lower_bound, upper_bound, lims = [0, 35])
# Out:
# Elapsed time: 5.84 seconds

# %%
worst_3 = Model(df, str(worst_cantons[2]))

X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = worst_3.partition()

y_pred_point, lower_bound, upper_bound = worst_3.prediction_intervals_aci("xgb", X_combined, y_combined, X_test, y_test, epsilon, alpha=0.05, gamma=0.005, n_resamplings=100, full = True)

worst_3.serie_temp_canton("xgb", y_pred_point, lower_bound, upper_bound, lims = [0, 35])
# Out:
# Elapsed time: 5.61 seconds
