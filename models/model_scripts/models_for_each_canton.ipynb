# %% [markdown]
# # Model results for each canton
#
# 1. reg reg
# 2. reg rf
# 3. reg

# %% [markdown]
# ## Initial configuration

# %%
import pandas as pd
import sys
import numpy as np

sys.path.append('../../models')

from model_rr import Model

# %%
df = pd.read_csv('../../data/clean/full_data.csv')

# %%
cantons = [101, 102, 103, 104, 105, 106, 107, 108, 109, 110, 111, 112, 113, 114, 115, 116, 117, 118, 119, 120, 201, -202, 203, 204, 205, 206, 207, 208, 209, 210, 211, 212, 213, 214, 215, 216, 301, 302, 303, 304, 305, 306, 307, 308, 401, 402, 403, 404, 405, 406, 407, 408, 409, 410, 501, 502, 503, 504, 505, 506, 507, 508, 509, 510, 511, 601, 602, 603, 604, 605, 606, 607, 608, 609, 610, 611, 701, 702, 703, 704, 705, 706]

cantons = [str(x) for x in cantons]

# %% [markdown]
# # Random Forest

# %% [markdown]
# ## Fitting the models

# %%
for canton in cantons[0:10]: 
    instancia = Model(df, canton)
    X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = instancia.partition()
    instancia.rf_reg(X_combined, y_combined, X_test, y_test, test, pds, epsilon)
# Out:
# RF Model Ready for 101
# RF Model Ready for 102
# RF Model Ready for 103
# RF Model Ready for 104
# RF Model Ready for 105
# RF Model Ready for 106
# RF Model Ready for 107
# RF Model Ready for 108
# RF Model Ready for 109
# RF Model Ready for 110

# %%
for canton in cantons[10:20]: 
    instancia = Model(df, canton)
    X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = instancia.partition()
    instancia.rf_reg(X_combined, y_combined, X_test, y_test, test, pds, epsilon)
# Out:
# RF Model Ready for 111
# RF Model Ready for 112
# RF Model Ready for 113
# RF Model Ready for 114
# RF Model Ready for 115
# RF Model Ready for 116
# RF Model Ready for 117
# RF Model Ready for 118
# RF Model Ready for 119
# RF Model Ready for 120

# %%
instancia = Model(df, "201")
X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = instancia.partition()
instancia.rf_reg(X_combined, y_combined, X_test, y_test, test, pds, epsilon)
# Out:
# RF Model Ready for 201

# %%
for canton in cantons[22:30]: 
    instancia = Model(df, canton)
    X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = instancia.partition()
    instancia.rf_reg(X_combined, y_combined, X_test, y_test, test, pds, epsilon)
# Out:
# RF Model Ready for 203
# RF Model Ready for 204
# RF Model Ready for 205
# RF Model Ready for 206
# RF Model Ready for 207
# RF Model Ready for 208
# RF Model Ready for 209
# RF Model Ready for 210

# %%
instancia = Model(df, "-202")
X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = instancia.partition()
instancia.rf_reg(X_combined, y_combined, X_test, y_test, test, pds, epsilon)
# Out:
# RF Model Ready for -202

# %%
for canton in cantons[30:40]: 
    instancia = Model(df, canton)
    X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = instancia.partition()
    instancia.rf_reg(X_combined, y_combined, X_test, y_test, test, pds, epsilon)
# Out:
# RF Model Ready for 211
# RF Model Ready for 212
# RF Model Ready for 213
# RF Model Ready for 214
# RF Model Ready for 215
# RF Model Ready for 216
# RF Model Ready for 301
# RF Model Ready for 302
# RF Model Ready for 303
# RF Model Ready for 304

# %%
for canton in cantons[40:50]: 
    instancia = Model(df, canton)
    X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = instancia.partition()
    instancia.rf_reg(X_combined, y_combined, X_test, y_test, test, pds, epsilon)
# Out:
# RF Model Ready for 305
# RF Model Ready for 306
# RF Model Ready for 307
# RF Model Ready for 308
# RF Model Ready for 401
# RF Model Ready for 402
# RF Model Ready for 403
# RF Model Ready for 404
# RF Model Ready for 405
# RF Model Ready for 406

# %%
for canton in cantons[50:60]: 
    instancia = Model(df, canton)
    X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = instancia.partition()
    instancia.rf_reg(X_combined, y_combined, X_test, y_test, test, pds, epsilon)
# Out:
# RF Model Ready for 407
# RF Model Ready for 408
# RF Model Ready for 409
# RF Model Ready for 410
# RF Model Ready for 501
# RF Model Ready for 502
# RF Model Ready for 503
# RF Model Ready for 504
# RF Model Ready for 505
# RF Model Ready for 506

# %%
for canton in cantons[60:70]: 
    instancia = Model(df, canton)
    X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = instancia.partition()
    instancia.rf_reg(X_combined, y_combined, X_test, y_test, test, pds, epsilon)
# Out:
# RF Model Ready for 507
# RF Model Ready for 508
# RF Model Ready for 509
# RF Model Ready for 510
# RF Model Ready for 511
# RF Model Ready for 601
# RF Model Ready for 602
# RF Model Ready for 603
# RF Model Ready for 604
# RF Model Ready for 605

# %%
for canton in cantons[70:82]: 
    instancia = Model(df, canton)
    X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = instancia.partition()
    instancia.rf_reg(X_combined, y_combined, X_test, y_test, test, pds, epsilon)
# Out:
# RF Model Ready for 606
# RF Model Ready for 607
# RF Model Ready for 608
# RF Model Ready for 609
# RF Model Ready for 610
# RF Model Ready for 611
# RF Model Ready for 701
# RF Model Ready for 702
# RF Model Ready for 703
# RF Model Ready for 704
# RF Model Ready for 705
# RF Model Ready for 706

# %%
instancia = Model(df, "601") # Retrain after adding cantons that were not considered, Monteverde an PJ
X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = instancia.partition()
instancia.rf_reg(X_combined, y_combined, X_test, y_test, test, pds, epsilon)
# Out:
# RF Model Ready for 601

# %%
instancia = Model(df, "607") # Retrain after adding cantons that were not considered, Monteverde an PJ
X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = instancia.partition()
instancia.rf_reg(X_combined, y_combined, X_test, y_test, test, pds, epsilon)
# Out:
# RF Model Ready for 607

# %% [markdown]
# ## Save metrics

# %%
cod_cant_rf = []
nrmse_rf = []

for canton in cantons: 
    instancia = Model(df, canton)
    X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = instancia.partition()
    cant_temp, nrmse_temp = instancia.calculate_nrmse("rf", epsilon)
    cod_cant_rf.append(canton)
    nrmse_rf.append(nrmse_temp)

nrmse_rf = pd.DataFrame({"canton": cod_cant_rf,
                         "nrmse": nrmse_rf})

# %%
nrmse_rf.to_csv("../../data/model_results/metrics/rf.csv")

# %% [markdown]
# ## Best

# %%
nrmse_rf = pd.read_csv("../../data/model_results/metrics/rf.csv")

nrmse_rf = nrmse_rf[np.isfinite(nrmse_rf)] # Prevent using cantons with an NRMSE undefined because their mean cases is 0
nrmse_rf = nrmse_rf[nrmse_rf["nrmse"].notnull()] # Prevent using cantons with an NRMSE undefined because their mean cases is 0

# %%
nrmse_rf = pd.read_csv("../../data/model_results/metrics/rf.csv")

best_rf = Model(df, cantons[nrmse_rf["nrmse"].idxmin()])

# %% [markdown]
# ### Plot results

# %%
X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = best_rf.partition()
y_pred_point, lower_bound, upper_bound = best_rf.prediction_intervals(X_combined, y_combined, X_test, epsilon, "rf", repeats = 100)
best_rf.serie_temp_canton("rf", y_pred_point, lower_bound, upper_bound)

# %% [markdown]
# ### Confidence interval for NRMSE

# %%
print(f"Best canton NRMSE: {round(nrmse_rf.iloc[nrmse_rf["nrmse"].idxmin(), 2], 4)}")
# Out:
# Best canton NRMSE: 0.1263

# %%
X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = best_rf.partition()
best_rf.confint_nrmse("rf", X_combined, y_combined, X_test, y_test, epsilon, n_bootstraps = 100)
# Out:
# point estimate: 0.69
# lower bound: 0.0, upper bound: 3.67

# %% [markdown]
# ### Feature importance

# %%
X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = best_rf.partition()
best_rf.var_importance(X_test, y_test, "rf", repeats = 100, var = "RR")
# Out:
#                  Feature    imp_rf    std_rf
# 0    precip_median_lag_4  0.001061  0.001236
# 1           fiebre_lag_4  0.000957  0.001384
# 2       vacaciones_lag_3  0.000533  0.000714
# 3               rr_lag_2  0.000000  0.000000
# 4               rr_lag_3  0.000000  0.000000
# ..                   ...       ...       ...
# 101     precip_min_lag_4  0.000000  0.000000
# 102     precip_min_lag_1  0.000000  0.000000
# 103     precip_min_lag_2  0.000000  0.000000
# 104                urb_0  0.000000  0.000000
# 105         empleo_lag_2 -0.000237  0.000215
#
# [106 rows x 3 columns]
#                  Feature    imp_rf    std_rf
# 0    precip_median_lag_4  0.001061  0.001236
# 1           fiebre_lag_4  0.000957  0.001384
# 2       vacaciones_lag_3  0.000533  0.000714
# 3               rr_lag_2  0.000000  0.000000
# 4               rr_lag_3  0.000000  0.000000
# ..                   ...       ...       ...
# 101     precip_min_lag_4  0.000000  0.000000
# 102     precip_min_lag_1  0.000000  0.000000
# 103     precip_min_lag_2  0.000000  0.000000
# 104                urb_0  0.000000  0.000000
# 105         empleo_lag_2 -0.000237  0.000215
#
# [106 rows x 3 columns]

# %% [markdown]
# ### Feature selection

# %%
X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = best_rf.partition()
best_rf.rfecv_selection("rf", X_combined, y_combined, X_test, y_test, pds, epsilon, repeats = 100, var = "RR")
# Out:
# Optimal number of features for RR and rf: 5
# Selected features: ['tmin_mean_lag_3', 'tmin_mean_lag_1', 'aedes_aegypti_lag_1', 'comprar_carro_lag_3', 'corte_de_agua_lag_3']
# New NRMSE with selected features: -0.0000

# %% [markdown]
# ## Worst

# %%
nrmse_rf = pd.read_csv("../../data/model_results/metrics/rf.csv")

nrmse_rf = nrmse_rf[np.isfinite(nrmse_rf)] # Prevent using cantons with an NRMSE undefined because their mean cases is 0
nrmse_rf = nrmse_rf[nrmse_rf["nrmse"].notnull()] # Prevent using cantons with an NRMSE undefined because their mean cases is 0

# %%
worst_rf = Model(df, cantons[nrmse_rf["nrmse"].idxmax()])

# %% [markdown]
# ### Plot results

# %%
X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = worst_rf.partition()
y_pred_point, lower_bound, upper_bound = worst_rf.prediction_intervals(X_combined, y_combined, X_test, epsilon, "rf", repeats = 100)
worst_rf.serie_temp_canton("rf", y_pred_point, lower_bound, upper_bound)

# %% [markdown]
# ### Confidence interval for NRMSE

# %%
print(f"Worst canton NRMSE for RF: {round(nrmse_rf.iloc[nrmse_rf["nrmse"].idxmax(), 2], 4)}")
# Out:
# Worst canton NRMSE for RF: 3.6835

# %%
X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = worst_rf.partition()
worst_rf.confint_nrmse("rf", X_combined, y_combined, X_test, y_test, epsilon, n_bootstraps = 100)
# Out:
# point estimate: 3.77
# lower bound: 3.59, upper bound: 4.41

# %% [markdown]
# ### Feature importance

# %%
X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = worst_rf.partition()
worst_rf.var_importance(X_test, y_test, "rf", repeats = 100, var = "RR")
# Out:
#                  Feature    imp_rf    std_rf
# 0    precip_median_lag_3  0.005996  0.008159
# 1       precip_max_lag_4  0.005059  0.002039
# 2        temp_prom_lag_3  0.003802  0.001524
# 3               rr_lag_2  0.003765  0.012648
# 4               rr_lag_4  0.003560  0.010153
# ..                   ...       ...       ...
# 101         empleo_lag_3 -0.002803  0.011039
# 102             rr_lag_1 -0.003897  0.055933
# 103         fiebre_lag_4 -0.004957  0.015268
# 104           ndvi_lag_3 -0.023979  0.019591
# 105           ndvi_lag_4 -0.024527  0.016506
#
# [106 rows x 3 columns]
#                  Feature    imp_rf    std_rf
# 0    precip_median_lag_3  0.005996  0.008159
# 1       precip_max_lag_4  0.005059  0.002039
# 2        temp_prom_lag_3  0.003802  0.001524
# 3               rr_lag_2  0.003765  0.012648
# 4               rr_lag_4  0.003560  0.010153
# ..                   ...       ...       ...
# 101         empleo_lag_3 -0.002803  0.011039
# 102             rr_lag_1 -0.003897  0.055933
# 103         fiebre_lag_4 -0.004957  0.015268
# 104           ndvi_lag_3 -0.023979  0.019591
# 105           ndvi_lag_4 -0.024527  0.016506
#
# [106 rows x 3 columns]

# %% [markdown]
# ### Feature selection

# %%
X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = worst_rf.partition()
worst_rf.rfecv_selection("rf", X_combined, y_combined, X_test, y_test, pds, epsilon, repeats = 100, var = "RR")
# Out:
# Optimal number of features for RR and rf: 7
# Selected features: ['rr_lag_4', 'rr_lag_3', 'rr_lag_2', 'rr_lag_1', 'ndvi_lag_4', 'nino34ssta_lag_1', 'dengue_lag_1']
# New NRMSE with selected features: -0.6607

# %% [markdown]
# # XGB

# %% [markdown]
# ## Fit models

# %%
for canton in cantons[0:10]: 
    instancia = Model(df, canton)
    X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = instancia.partition()
    instancia.xgb_reg(X_combined, y_combined, X_test, y_test, test, pds, epsilon)
# Out:
# XGB Model Ready for 101
# XGB Model Ready for 102
# XGB Model Ready for 103
# XGB Model Ready for 104
# XGB Model Ready for 105
# XGB Model Ready for 106
# XGB Model Ready for 107
# XGB Model Ready for 108
# XGB Model Ready for 109
# XGB Model Ready for 110

# %%
for canton in cantons[10:20]: 
    instancia = Model(df, canton)
    X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = instancia.partition()
    instancia.xgb_reg(X_combined, y_combined, X_test, y_test, test, pds, epsilon)
# Out:
# XGB Model Ready for 111
# XGB Model Ready for 112
# XGB Model Ready for 113
# XGB Model Ready for 114
# XGB Model Ready for 115
# XGB Model Ready for 116
# XGB Model Ready for 117
# XGB Model Ready for 118
# XGB Model Ready for 119
# XGB Model Ready for 120

# %%
instancia = Model(df, "201")
X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = instancia.partition()
instancia.xgb_reg(X_combined, y_combined, X_test, y_test, test, pds, epsilon)
# Out:
# XGB Model Ready for 201

# %%
for canton in cantons[22:30]: 
    instancia = Model(df, canton)
    X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = instancia.partition()
    instancia.xgb_reg(X_combined, y_combined, X_test, y_test, test, pds, epsilon)
# Out:
# XGB Model Ready for 203
# XGB Model Ready for 204
# XGB Model Ready for 205
# XGB Model Ready for 206
# XGB Model Ready for 207
# XGB Model Ready for 208
# XGB Model Ready for 209
# XGB Model Ready for 210

# %%
instancia = Model(df, "-202")
X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = instancia.partition()
instancia.xgb_reg(X_combined, y_combined, X_test, y_test, test, pds, epsilon)
# Out:
# XGB Model Ready for -202

# %%
for canton in cantons[30:40]: 
    instancia = Model(df, canton)
    X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = instancia.partition()
    instancia.xgb_reg(X_combined, y_combined, X_test, y_test, test, pds, epsilon)
# Out:
# XGB Model Ready for 211
# XGB Model Ready for 212
# XGB Model Ready for 213
# XGB Model Ready for 214
# XGB Model Ready for 215
# XGB Model Ready for 216
# XGB Model Ready for 301
# XGB Model Ready for 302
# XGB Model Ready for 303
# XGB Model Ready for 304

# %%
for canton in cantons[40:50]: 
    instancia = Model(df, canton)
    X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = instancia.partition()
    instancia.xgb_reg(X_combined, y_combined, X_test, y_test, test, pds, epsilon)
# Out:
# XGB Model Ready for 305
# XGB Model Ready for 306
# XGB Model Ready for 307
# XGB Model Ready for 308
# XGB Model Ready for 401
# XGB Model Ready for 402
# XGB Model Ready for 403
# XGB Model Ready for 404
# XGB Model Ready for 405
# XGB Model Ready for 406

# %%
for canton in cantons[50:60]: 
    instancia = Model(df, canton)
    X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = instancia.partition()
    instancia.xgb_reg(X_combined, y_combined, X_test, y_test, test, pds, epsilon)
# Out:
# XGB Model Ready for 407
# XGB Model Ready for 408
# XGB Model Ready for 409
# XGB Model Ready for 410
# XGB Model Ready for 501
# XGB Model Ready for 502
# XGB Model Ready for 503
# XGB Model Ready for 504
# XGB Model Ready for 505
# XGB Model Ready for 506

# %%
for canton in cantons[60:70]: 
    instancia = Model(df, canton)
    X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = instancia.partition()
    instancia.xgb_reg(X_combined, y_combined, X_test, y_test, test, pds, epsilon)
# Out:
# XGB Model Ready for 507
# XGB Model Ready for 508
# XGB Model Ready for 509
# XGB Model Ready for 510
# XGB Model Ready for 511
# XGB Model Ready for 601
# XGB Model Ready for 602
# XGB Model Ready for 603
# XGB Model Ready for 604
# XGB Model Ready for 605

# %%
for canton in cantons[70:82]: 
    instancia = Model(df, canton)
    X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = instancia.partition()
    instancia.xgb_reg(X_combined, y_combined, X_test, y_test, test, pds, epsilon)
# Out:
# XGB Model Ready for 606
# XGB Model Ready for 607
# XGB Model Ready for 608
# XGB Model Ready for 609
# XGB Model Ready for 610
# XGB Model Ready for 611
# XGB Model Ready for 701
# XGB Model Ready for 702
# XGB Model Ready for 703
# XGB Model Ready for 704
# XGB Model Ready for 705
# XGB Model Ready for 706

# %%
instancia = Model(df, "601") # Retrain with cantons that were not considered
X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = instancia.partition()
instancia.xgb_reg(X_combined, y_combined, X_test, y_test, test, pds, epsilon)
# Out:
# XGB Model Ready for 601

# %%
instancia = Model(df, "607") # Retrain with cantons that were not considered
X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = instancia.partition()
instancia.xgb_reg(X_combined, y_combined, X_test, y_test, test, pds, epsilon)
# Out:
# XGB Model Ready for 607

# %% [markdown]
# ## Save metrics

# %%
cod_cant_xgb = []
nrmse_xgb = []

for canton in cantons: 
    instancia = Model(df, canton)
    X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = instancia.partition()
    cant_temp, nrmse_temp = instancia.calculate_nrmse("xgb", epsilon)
    cod_cant_xgb.append(canton)
    nrmse_xgb.append(nrmse_temp)

nrmse_xgb = pd.DataFrame({"canton": cod_cant_xgb,
                         "nrmse": nrmse_xgb})

nrmse_xgb.to_csv("../../data/model_results/metrics/xgb.csv")

# %% [markdown]
# ## Best

# %%
nrmse_xgb = pd.read_csv("../../data/model_results/metrics/xgb.csv")

nrmse_xgb = nrmse_xgb[np.isfinite(nrmse_xgb)] # Prevent using cantons with an NRMSE undefined because their mean cases is 0
nrmse_xgb = nrmse_xgb[nrmse_xgb["nrmse"].notnull()] # Prevent using cantons with an NRMSE undefined because their mean cases is 0

# %%
best_xgb = Model(df, cantons[nrmse_xgb["nrmse"].idxmin()])

# %% [markdown]
# ### Plot results

# %%
X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = best_xgb.partition()
y_pred_point, lower_bound, upper_bound = best_xgb.prediction_intervals(X_combined, y_combined, X_test, epsilon, "xgb", repeats = 100)
best_xgb.serie_temp_canton("xgb", y_pred_point, lower_bound, upper_bound)

# %% [markdown]
# ### Confidence interval for NRMSE

# %%
print(f"Best canton NRMSE for XGB: {round(nrmse_xgb.iloc[nrmse_xgb["nrmse"].idxmin(), 2], 4)}")
# Out:
# Best canton NRMSE for XGB: 0.4422

# %%
X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = best_xgb.partition()
best_xgb.confint_nrmse("xgb", X_combined, y_combined, X_test, y_test, epsilon, n_bootstraps = 100)
# Out:
# point estimate: 0.54
# lower bound: 0.39, upper bound: 0.98

# %% [markdown]
# ### Feature importance

# %%
X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = best_xgb.partition()
best_xgb.var_importance(X_test, y_test, "xgb", repeats = 100, var = "RR")
# Out:
#                 Feature   imp_xgb   std_xgb
# 0              rr_lag_1  0.065401  0.042997
# 1            nino34ssta  0.057664  0.027593
# 2      vacaciones_lag_1  0.002646  0.001250
# 3          fiebre_lag_1  0.001539  0.002145
# 4              rr_lag_4  0.001489  0.005756
# ..                  ...       ...       ...
# 101  precip_total_lag_3 -0.000559  0.001976
# 102        empleo_lag_1 -0.002323  0.003996
# 103          ndvi_lag_1 -0.011739  0.006708
# 104        fiebre_lag_3 -0.019686  0.013734
# 105          ndvi_lag_2 -0.041829  0.023669
#
# [106 rows x 3 columns]
#                 Feature   imp_xgb   std_xgb
# 0              rr_lag_1  0.065401  0.042997
# 1            nino34ssta  0.057664  0.027593
# 2      vacaciones_lag_1  0.002646  0.001250
# 3          fiebre_lag_1  0.001539  0.002145
# 4              rr_lag_4  0.001489  0.005756
# ..                  ...       ...       ...
# 101  precip_total_lag_3 -0.000559  0.001976
# 102        empleo_lag_1 -0.002323  0.003996
# 103          ndvi_lag_1 -0.011739  0.006708
# 104        fiebre_lag_3 -0.019686  0.013734
# 105          ndvi_lag_2 -0.041829  0.023669
#
# [106 rows x 3 columns]

# %% [markdown]
# ### Feature selection

# %%
X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = best_xgb.partition()
best_xgb.rfecv_selection("xgb", X_combined, y_combined, X_test, y_test, pds, repeats = 100, var = "RR")
# Out:
# Optimal number of features for RR and xgb: 33
# Selected features: ['rr_lag_4', 'rr_lag_2', 'rr_lag_1', 'ndvi_lag_4', 'ndvi_lag_3', 'ndvi_lag_2', 'ndvi_lag_1', 'tmax_mean_lag_3', 'tmax_mean_lag_1', 'tmin_mean_lag_4', 'tmin_mean_lag_3', 'tmin_mean_lag_2', 'tmin_mean_lag_1', 'nino34ssta_lag_4', 'nino34ssta_lag_3', 'nino34ssta_lag_2', 'nino34ssta_lag_1', 'temp_prom_lag_2', 'fiebre_lag_3', 'fiebre_lag_1', 'desempleo_lag_2', 'empleo_lag_4', 'empleo_lag_3', 'empleo_lag_2', 'empleo_lag_1', 'vacaciones_lag_4', 'vacaciones_lag_3', 'vacaciones_lag_1', 'dengue_lag_1', 'precip_total_lag_4', 'precip_total_lag_3', 'precip_total_lag_1', 'precip_median_lag_4']
# New NRMSE with selected features: 0.4340

# %% [markdown]
# ## Worst

# %%
nrmse_xgb = pd.read_csv("../../data/model_results/metrics/xgb.csv")

nrmse_xgb = nrmse_xgb[np.isfinite(nrmse_xgb)] # Prevent using cantons with an NRMSE undefined because their mean cases is 0
nrmse_xgb = nrmse_xgb[nrmse_xgb["nrmse"].notnull()] # Prevent using cantons with an NRMSE undefined because their mean cases is 0

# %%
worst_xgb = Model(df, cantons[nrmse_xgb["nrmse"].idxmax()])

# %% [markdown]
# ### Plot results

# %%
X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = worst_xgb.partition()
y_pred_point, lower_bound, upper_bound = worst_xgb.prediction_intervals(X_combined, y_combined, X_test, epsilon, "xgb", repeats = 100)
worst_xgb.serie_temp_canton("xgb", y_pred_point, lower_bound, upper_bound)

# %% [markdown]
# ### Confidence interval for NRMSE

# %%
print(f"Worst canton NRMSE for XGB: {round(nrmse_xgb.iloc[nrmse_xgb["nrmse"].idxmax(), 2], 4)}")
# Out:
# Worst canton NRMSE for XGB: 2.6956

# %%
X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = worst_xgb.partition()
worst_xgb.confint_nrmse("xgb", X_combined, y_combined, X_test, y_test, epsilon, n_bootstraps = 100)
# Out:
# point estimate: 8.06
# lower bound: 7.21, upper bound: 9.53

# %% [markdown]
# ### Feature importance

# %%
X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = worst_xgb.partition()
worst_xgb.var_importance(X_test, y_test, "xgb", repeats = 100, var = "RR")
# Out:
#                 Feature   imp_xgb   std_xgb
# 0              rr_lag_1  0.015346  0.022191
# 1    precip_total_lag_4  0.011280  0.019538
# 2    precip_total_lag_1  0.004096  0.003857
# 3       tmin_mean_lag_1  0.001344  0.002174
# 4            ndvi_lag_2  0.000832  0.002203
# ..                  ...       ...       ...
# 101     temp_prom_lag_1 -0.000771  0.001496
# 102     tmin_mean_lag_4 -0.003391  0.002680
# 103    precip_max_lag_3 -0.004011  0.004124
# 104    precip_min_lag_1 -0.010661  0.006018
# 105    nino34ssta_lag_1 -0.010978  0.005821
#
# [106 rows x 3 columns]
#                 Feature   imp_xgb   std_xgb
# 0              rr_lag_1  0.015346  0.022191
# 1    precip_total_lag_4  0.011280  0.019538
# 2    precip_total_lag_1  0.004096  0.003857
# 3       tmin_mean_lag_1  0.001344  0.002174
# 4            ndvi_lag_2  0.000832  0.002203
# ..                  ...       ...       ...
# 101     temp_prom_lag_1 -0.000771  0.001496
# 102     tmin_mean_lag_4 -0.003391  0.002680
# 103    precip_max_lag_3 -0.004011  0.004124
# 104    precip_min_lag_1 -0.010661  0.006018
# 105    nino34ssta_lag_1 -0.010978  0.005821
#
# [106 rows x 3 columns]

# %% [markdown]
# ### Feature selection

# %%
X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = worst_xgb.partition()
worst_xgb.rfecv_selection("xgb", X_combined, y_combined, X_test, y_test, pds, repeats = 100, var = "RR")
# Out:
# Optimal number of features for RR and xgb: 15
# Selected features: ['rr_lag_1', 'tmin_mean_lag_1', 'nino34ssta_lag_2', 'nino34ssta_lag_1', 'temp_prom_lag_4', 'temp_prom_lag_3', 'aedes_aegypti_lag_4', 'fiebre_lag_3', 'fiebre_lag_2', 'empleo_lag_1', 'tiquetes_avion_lag_1', 'vacaciones_lag_2', 'precip_total_lag_4', 'precip_max_lag_3', 'precip_min_lag_1']
# New NRMSE with selected features: -0.2080

# %% [markdown]
# # HRF

# %% [markdown]
# ## Fit models

# %%
for canton in cantons[0:10]: 
    instancia = Model(df, canton)
    X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = instancia.partition()
    instancia.hybrid("hrf", X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon)
# Out:
# WARNING: Test set only contains one label: 1
# Only one class present in test set for classification. Skipping classification step.
# Using PredefinedSplit: n_train=52, n_val=149
# hrf ready for 101
#               precision    recall  f1-score   support
#
#            0       0.50      0.65      0.57        26
#            1       0.50      0.35      0.41        26
#
#     accuracy                           0.50        52
#    macro avg       0.50      0.50      0.49        52
# weighted avg       0.50      0.50      0.49        52
#
# Using PredefinedSplit: n_train=37, n_val=32
# hrf ready for 102
# c:\Users\nan\OneDrive\Documentos\ucr\practica profesiona\dengue-model\.venv\Lib\site-packages\sklearn\model_selection\_search.py:1137: UserWarning: One or more of the test scores are non-finite: [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan]
#   warnings.warn(
#               precision    recall  f1-score   support
#
#            0       0.28      0.38      0.32        13
#            1       0.76      0.67      0.71        39
#
#     accuracy                           0.60        52
#    macro avg       0.52      0.53      0.52        52
# weighted avg       0.64      0.60      0.61        52
#
# Using PredefinedSplit: n_train=52, n_val=71
# hrf ready for 103
# Threshold tuning failed: The provided estimator makes constant predictions. Therefore, it is impossible to optimize the decision threshold.
# Using best classifier directly without threshold tuning.
#               precision    recall  f1-score   support
#
#            0       0.83      0.79      0.81        43
#            1       0.18      0.22      0.20         9
#
#     accuracy                           0.69        52
#    macro avg       0.51      0.51      0.50        52
# weighted avg       0.72      0.69      0.70        52
#
# Using PredefinedSplit: n_train=41, n_val=41
# hrf ready for 104
#               precision    recall  f1-score   support
#
#            0       0.94      0.31      0.46        49
#            1       0.06      0.67      0.10         3
#
#     accuracy                           0.33        52
#    macro avg       0.50      0.49      0.28        52
# weighted avg       0.89      0.33      0.44        52
#
# Using PredefinedSplit: n_train=1, n_val=11
# hrf ready for 105
#               precision    recall  f1-score   support
#
#            0       0.50      0.39      0.44        33
#            1       0.23      0.32      0.27        19
#
#     accuracy                           0.37        52
#    macro avg       0.37      0.35      0.35        52
# weighted avg       0.40      0.37      0.38        52
#
# Using PredefinedSplit: n_train=43, n_val=32
# hrf ready for 106
#               precision    recall  f1-score   support
#
#            0       0.63      0.50      0.56        38
#            1       0.14      0.21      0.17        14
#
#     accuracy                           0.42        52
#    macro avg       0.38      0.36      0.36        52
# weighted avg       0.50      0.42      0.45        52
#
# Using PredefinedSplit: n_train=48, n_val=49
# hrf ready for 107
# Threshold tuning failed: The provided estimator makes constant predictions. Therefore, it is impossible to optimize the decision threshold.
# Using best classifier directly without threshold tuning.
#               precision    recall  f1-score   support
#
#            0       0.50      1.00      0.67        26
#            1       0.00      0.00      0.00        26
#
#     accuracy                           0.50        52
#    macro avg       0.25      0.50      0.33        52
# weighted avg       0.25      0.50      0.33        52
#
# Using PredefinedSplit: n_train=35, n_val=39
# c:\Users\nan\OneDrive\Documentos\ucr\practica profesiona\dengue-model\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\nan\OneDrive\Documentos\ucr\practica profesiona\dengue-model\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\nan\OneDrive\Documentos\ucr\practica profesiona\dengue-model\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# hrf ready for 108
# c:\Users\nan\OneDrive\Documentos\ucr\practica profesiona\dengue-model\.venv\Lib\site-packages\sklearn\model_selection\_search.py:1137: UserWarning: One or more of the test scores are non-finite: [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan]
#   warnings.warn(
#               precision    recall  f1-score   support
#
#            0       0.16      0.50      0.24         8
#            1       0.85      0.52      0.65        44
#
#     accuracy                           0.52        52
#    macro avg       0.51      0.51      0.45        52
# weighted avg       0.75      0.52      0.59        52
#
# Using PredefinedSplit: n_train=52, n_val=92
# hrf ready for 109
# c:\Users\nan\OneDrive\Documentos\ucr\practica profesiona\dengue-model\.venv\Lib\site-packages\sklearn\model_selection\_search.py:1137: UserWarning: One or more of the test scores are non-finite: [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan]
#   warnings.warn(
# c:\Users\nan\OneDrive\Documentos\ucr\practica profesiona\dengue-model\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\nan\OneDrive\Documentos\ucr\practica profesiona\dengue-model\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\nan\OneDrive\Documentos\ucr\practica profesiona\dengue-model\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         5
#            1       0.90      1.00      0.95        47
#
#     accuracy                           0.90        52
#    macro avg       0.45      0.50      0.47        52
# weighted avg       0.82      0.90      0.86        52
#
# Using PredefinedSplit: n_train=52, n_val=54
# hrf ready for 110

# %%
for canton in cantons[10:20]: 
    instancia = Model(df, canton)
    X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = instancia.partition()
    instancia.hybrid("hrf", X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon)
# Out:
# c:\Users\nan\OneDrive\Documentos\ucr\practica profesiona\dengue-model\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\nan\OneDrive\Documentos\ucr\practica profesiona\dengue-model\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\nan\OneDrive\Documentos\ucr\practica profesiona\dengue-model\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
#               precision    recall  f1-score   support
#
#            0       0.83      1.00      0.91        43
#            1       0.00      0.00      0.00         9
#
#     accuracy                           0.83        52
#    macro avg       0.41      0.50      0.45        52
# weighted avg       0.68      0.83      0.75        52
#
# Using PredefinedSplit: n_train=17, n_val=24
# hrf ready for 111
# c:\Users\nan\OneDrive\Documentos\ucr\practica profesiona\dengue-model\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\nan\OneDrive\Documentos\ucr\practica profesiona\dengue-model\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\nan\OneDrive\Documentos\ucr\practica profesiona\dengue-model\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        44
#            1       0.15      1.00      0.27         8
#
#     accuracy                           0.15        52
#    macro avg       0.08      0.50      0.13        52
# weighted avg       0.02      0.15      0.04        52
#
# Using PredefinedSplit: n_train=22, n_val=25
# hrf ready for 112
# Threshold tuning failed: The provided estimator makes constant predictions. Therefore, it is impossible to optimize the decision threshold.
# Using best classifier directly without threshold tuning.
#               precision    recall  f1-score   support
#
#            0       0.47      0.84      0.60        25
#            1       0.43      0.11      0.18        27
#
#     accuracy                           0.46        52
#    macro avg       0.45      0.48      0.39        52
# weighted avg       0.45      0.46      0.38        52
#
# Using PredefinedSplit: n_train=45, n_val=51
# hrf ready for 113
# Threshold tuning failed: The provided estimator makes constant predictions. Therefore, it is impossible to optimize the decision threshold.
# Using best classifier directly without threshold tuning.
#               precision    recall  f1-score   support
#
#            0       0.79      1.00      0.88        41
#            1       0.00      0.00      0.00        11
#
#     accuracy                           0.79        52
#    macro avg       0.39      0.50      0.44        52
# weighted avg       0.62      0.79      0.70        52
#
# Using PredefinedSplit: n_train=19, n_val=27
# c:\Users\nan\OneDrive\Documentos\ucr\practica profesiona\dengue-model\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\nan\OneDrive\Documentos\ucr\practica profesiona\dengue-model\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\nan\OneDrive\Documentos\ucr\practica profesiona\dengue-model\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# hrf ready for 114
# Threshold tuning failed: The provided estimator makes constant predictions. Therefore, it is impossible to optimize the decision threshold.
# Using best classifier directly without threshold tuning.
#               precision    recall  f1-score   support
#
#            0       0.83      1.00      0.91        43
#            1       0.00      0.00      0.00         9
#
#     accuracy                           0.83        52
#    macro avg       0.41      0.50      0.45        52
# weighted avg       0.68      0.83      0.75        52
#
# Using PredefinedSplit: n_train=32, n_val=33
# c:\Users\nan\OneDrive\Documentos\ucr\practica profesiona\dengue-model\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\nan\OneDrive\Documentos\ucr\practica profesiona\dengue-model\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\nan\OneDrive\Documentos\ucr\practica profesiona\dengue-model\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# hrf ready for 115
# Threshold tuning failed: The provided estimator makes constant predictions. Therefore, it is impossible to optimize the decision threshold.
# Using best classifier directly without threshold tuning.
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99        51
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.98        52
#    macro avg       0.49      0.50      0.50        52
# weighted avg       0.96      0.98      0.97        52
#
# Using PredefinedSplit: n_train=16, n_val=28
# c:\Users\nan\OneDrive\Documentos\ucr\practica profesiona\dengue-model\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\nan\OneDrive\Documentos\ucr\practica profesiona\dengue-model\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\nan\OneDrive\Documentos\ucr\practica profesiona\dengue-model\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# hrf ready for 116
# WARNING: Test set only contains one label: 0
# Only one class present in test set for classification. Skipping classification step.
# WARNING: No positive cases in some set (n_train=0, n_val=6). Using cv=5.
# hrf ready for 117
# Threshold tuning failed: The provided estimator makes constant predictions. Therefore, it is impossible to optimize the decision threshold.
# Using best classifier directly without threshold tuning.
#               precision    recall  f1-score   support
#
#            0       0.52      1.00      0.68        27
#            1       0.00      0.00      0.00        25
#
#     accuracy                           0.52        52
#    macro avg       0.26      0.50      0.34        52
# weighted avg       0.27      0.52      0.35        52
#
# Using PredefinedSplit: n_train=41, n_val=34
# c:\Users\nan\OneDrive\Documentos\ucr\practica profesiona\dengue-model\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\nan\OneDrive\Documentos\ucr\practica profesiona\dengue-model\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\nan\OneDrive\Documentos\ucr\practica profesiona\dengue-model\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# hrf ready for 118
#               precision    recall  f1-score   support
#
#            0       0.55      0.67      0.60        24
#            1       0.65      0.54      0.59        28
#
#     accuracy                           0.60        52
#    macro avg       0.60      0.60      0.60        52
# weighted avg       0.61      0.60      0.60        52
#
# Using PredefinedSplit: n_train=45, n_val=148
# hrf ready for 119
#               precision    recall  f1-score   support
#
#            0       0.97      0.75      0.84        51
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.73        52
#    macro avg       0.49      0.37      0.42        52
# weighted avg       0.96      0.73      0.83        52
#
# Using PredefinedSplit: n_train=3, n_val=7
# hrf ready for 120

# %%
instancia = Model(df, "201")
X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = instancia.partition()
instancia.hybrid("hrf", X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon)
# Out:
# WARNING: Test set only contains one label: 1
# Only one class present in test set for classification. Skipping classification step.
# Using PredefinedSplit: n_train=52, n_val=151
# hrf ready for 201

# %%
for canton in cantons[22:30]: 
    instancia = Model(df, canton)
    X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = instancia.partition()
    instancia.hybrid("hrf", X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.71      0.86      0.78        37
#            1       0.29      0.13      0.18        15
#
#     accuracy                           0.65        52
#    macro avg       0.50      0.50      0.48        52
# weighted avg       0.59      0.65      0.61        52
#
# Using PredefinedSplit: n_train=50, n_val=58
# hrf ready for 203
#               precision    recall  f1-score   support
#
#            0       0.94      0.66      0.78        47
#            1       0.16      0.60      0.25         5
#
#     accuracy                           0.65        52
#    macro avg       0.55      0.63      0.51        52
# weighted avg       0.86      0.65      0.72        52
#
# Using PredefinedSplit: n_train=29, n_val=41
# hrf ready for 204
# c:\Users\nan\OneDrive\Documentos\ucr\practica profesiona\dengue-model\.venv\Lib\site-packages\sklearn\model_selection\_search.py:1137: UserWarning: One or more of the test scores are non-finite: [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan]
#   warnings.warn(
#               precision    recall  f1-score   support
#
#            0       0.85      0.44      0.58        25
#            1       0.64      0.93      0.76        27
#
#     accuracy                           0.69        52
#    macro avg       0.74      0.68      0.67        52
# weighted avg       0.74      0.69      0.67        52
#
# Using PredefinedSplit: n_train=52, n_val=99
# hrf ready for 205
#               precision    recall  f1-score   support
#
#            0       0.67      0.56      0.61        36
#            1       0.27      0.38      0.32        16
#
#     accuracy                           0.50        52
#    macro avg       0.47      0.47      0.46        52
# weighted avg       0.55      0.50      0.52        52
#
# Using PredefinedSplit: n_train=26, n_val=56
# hrf ready for 206
#               precision    recall  f1-score   support
#
#            0       0.79      0.55      0.65        42
#            1       0.17      0.40      0.24        10
#
#     accuracy                           0.52        52
#    macro avg       0.48      0.47      0.45        52
# weighted avg       0.67      0.52      0.57        52
#
# Using PredefinedSplit: n_train=49, n_val=21
# hrf ready for 207
#               precision    recall  f1-score   support
#
#            0       0.79      0.66      0.72        41
#            1       0.22      0.36      0.28        11
#
#     accuracy                           0.60        52
#    macro avg       0.51      0.51      0.50        52
# weighted avg       0.67      0.60      0.63        52
#
# Using PredefinedSplit: n_train=40, n_val=58
# hrf ready for 208
#               precision    recall  f1-score   support
#
#            0       0.59      0.38      0.46        34
#            1       0.30      0.50      0.38        18
#
#     accuracy                           0.42        52
#    macro avg       0.45      0.44      0.42        52
# weighted avg       0.49      0.42      0.43        52
#
# Using PredefinedSplit: n_train=44, n_val=121
# hrf ready for 209
# c:\Users\nan\OneDrive\Documentos\ucr\practica profesiona\dengue-model\.venv\Lib\site-packages\sklearn\model_selection\_search.py:1137: UserWarning: One or more of the test scores are non-finite: [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan]
#   warnings.warn(
# c:\Users\nan\OneDrive\Documentos\ucr\practica profesiona\dengue-model\.venv\Lib\site-packages\sklearn\model_selection\_split.py:813: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# c:\Users\nan\OneDrive\Documentos\ucr\practica profesiona\dengue-model\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\nan\OneDrive\Documentos\ucr\practica profesiona\dengue-model\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\nan\OneDrive\Documentos\ucr\practica profesiona\dengue-model\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        10
#            1       0.81      1.00      0.89        42
#
#     accuracy                           0.81        52
#    macro avg       0.40      0.50      0.45        52
# weighted avg       0.65      0.81      0.72        52
#
# Using PredefinedSplit: n_train=52, n_val=198
# hrf ready for 210

# %%
instancia = Model(df, "-202")
X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = instancia.partition()
instancia.hybrid("hrf", X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon)
# Out:
# Threshold tuning failed: The provided estimator makes constant predictions. Therefore, it is impossible to optimize the decision threshold.
# Using best classifier directly without threshold tuning.
#               precision    recall  f1-score   support
#
#            0       0.65      1.00      0.79        34
#            1       0.00      0.00      0.00        18
#
#     accuracy                           0.65        52
#    macro avg       0.33      0.50      0.40        52
# weighted avg       0.43      0.65      0.52        52
#
# Using PredefinedSplit: n_train=38, n_val=39
# c:\Users\nan\OneDrive\Documentos\ucr\practica profesiona\dengue-model\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\nan\OneDrive\Documentos\ucr\practica profesiona\dengue-model\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\nan\OneDrive\Documentos\ucr\practica profesiona\dengue-model\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# hrf ready for -202

# %%
for canton in cantons[30:40]: 
    instancia = Model(df, canton)
    X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = instancia.partition()
    instancia.hybrid("hrf", X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon)
# Out:
# Threshold tuning failed: The provided estimator makes constant predictions. Therefore, it is impossible to optimize the decision threshold.
# Using best classifier directly without threshold tuning.
# c:\Users\nan\OneDrive\Documentos\ucr\practica profesiona\dengue-model\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\nan\OneDrive\Documentos\ucr\practica profesiona\dengue-model\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\nan\OneDrive\Documentos\ucr\practica profesiona\dengue-model\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99        51
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.98        52
#    macro avg       0.49      0.50      0.50        52
# weighted avg       0.96      0.98      0.97        52
#
# Using PredefinedSplit: n_train=1, n_val=4
# hrf ready for 211
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98        51
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.96        52
#    macro avg       0.49      0.49      0.49        52
# weighted avg       0.96      0.96      0.96        52
#
# Using PredefinedSplit: n_train=27, n_val=17
# hrf ready for 212
# Threshold tuning failed: The provided estimator makes constant predictions. Therefore, it is impossible to optimize the decision threshold.
# Using best classifier directly without threshold tuning.
#               precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92        44
#            1       0.00      0.00      0.00         8
#
#     accuracy                           0.85        52
#    macro avg       0.42      0.50      0.46        52
# weighted avg       0.72      0.85      0.78        52
#
# Using PredefinedSplit: n_train=17, n_val=41
# c:\Users\nan\OneDrive\Documentos\ucr\practica profesiona\dengue-model\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\nan\OneDrive\Documentos\ucr\practica profesiona\dengue-model\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\nan\OneDrive\Documentos\ucr\practica profesiona\dengue-model\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# hrf ready for 213
#               precision    recall  f1-score   support
#
#            0       0.84      0.75      0.79        28
#            1       0.74      0.83      0.78        24
#
#     accuracy                           0.79        52
#    macro avg       0.79      0.79      0.79        52
# weighted avg       0.79      0.79      0.79        52
#
# Using PredefinedSplit: n_train=39, n_val=93
# hrf ready for 214
# c:\Users\nan\OneDrive\Documentos\ucr\practica profesiona\dengue-model\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\nan\OneDrive\Documentos\ucr\practica profesiona\dengue-model\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\nan\OneDrive\Documentos\ucr\practica profesiona\dengue-model\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
#               precision    recall  f1-score   support
#
#            0       0.83      1.00      0.91        43
#            1       0.00      0.00      0.00         9
#
#     accuracy                           0.83        52
#    macro avg       0.41      0.50      0.45        52
# weighted avg       0.68      0.83      0.75        52
#
# Using PredefinedSplit: n_train=18, n_val=24
# hrf ready for 215
#               precision    recall  f1-score   support
#
#            0       0.70      0.55      0.62        38
#            1       0.23      0.36      0.28        14
#
#     accuracy                           0.50        52
#    macro avg       0.46      0.45      0.45        52
# weighted avg       0.57      0.50      0.53        52
#
# Using PredefinedSplit: n_train=48, n_val=82
# hrf ready for 216
#               precision    recall  f1-score   support
#
#            0       0.60      0.50      0.55        36
#            1       0.18      0.25      0.21        16
#
#     accuracy                           0.42        52
#    macro avg       0.39      0.38      0.38        52
# weighted avg       0.47      0.42      0.44        52
#
# Using PredefinedSplit: n_train=27, n_val=37
# hrf ready for 301
#               precision    recall  f1-score   support
#
#            0       0.75      0.66      0.70        41
#            1       0.12      0.18      0.15        11
#
#     accuracy                           0.56        52
#    macro avg       0.44      0.42      0.42        52
# weighted avg       0.62      0.56      0.58        52
#
# Using PredefinedSplit: n_train=30, n_val=22
# hrf ready for 302
#               precision    recall  f1-score   support
#
#            0       0.55      0.24      0.33        25
#            1       0.54      0.81      0.65        27
#
#     accuracy                           0.54        52
#    macro avg       0.54      0.53      0.49        52
# weighted avg       0.54      0.54      0.50        52
#
# Using PredefinedSplit: n_train=38, n_val=47
# hrf ready for 303
#               precision    recall  f1-score   support
#
#            0       0.87      0.91      0.89        45
#            1       0.20      0.14      0.17         7
#
#     accuracy                           0.81        52
#    macro avg       0.54      0.53      0.53        52
# weighted avg       0.78      0.81      0.79        52
#
# Using PredefinedSplit: n_train=49, n_val=122
# hrf ready for 304

# %%
for canton in cantons[40:50]: 
    instancia = Model(df, canton)
    X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = instancia.partition()
    instancia.hybrid("hrf", X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon)
# Out:
# c:\Users\nan\OneDrive\Documentos\ucr\practica profesiona\dengue-model\.venv\Lib\site-packages\sklearn\model_selection\_search.py:1137: UserWarning: One or more of the test scores are non-finite: [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan]
#   warnings.warn(
#               precision    recall  f1-score   support
#
#            0       0.64      0.91      0.75        33
#            1       0.40      0.11      0.17        19
#
#     accuracy                           0.62        52
#    macro avg       0.52      0.51      0.46        52
# weighted avg       0.55      0.62      0.54        52
#
# Using PredefinedSplit: n_train=52, n_val=167
# hrf ready for 305
#               precision    recall  f1-score   support
#
#            0       0.87      0.85      0.86        46
#            1       0.00      0.00      0.00         6
#
#     accuracy                           0.75        52
#    macro avg       0.43      0.42      0.43        52
# weighted avg       0.77      0.75      0.76        52
#
# Using PredefinedSplit: n_train=3, n_val=9
# hrf ready for 306
#               precision    recall  f1-score   support
#
#            0       0.94      0.69      0.79        45
#            1       0.26      0.71      0.38         7
#
#     accuracy                           0.69        52
#    macro avg       0.60      0.70      0.59        52
# weighted avg       0.85      0.69      0.74        52
#
# Using PredefinedSplit: n_train=9, n_val=8
# hrf ready for 307
# Threshold tuning failed: The provided estimator makes constant predictions. Therefore, it is impossible to optimize the decision threshold.
# Using best classifier directly without threshold tuning.
#               precision    recall  f1-score   support
#
#            0       0.77      1.00      0.87        40
#            1       0.00      0.00      0.00        12
#
#     accuracy                           0.77        52
#    macro avg       0.38      0.50      0.43        52
# weighted avg       0.59      0.77      0.67        52
#
# Using PredefinedSplit: n_train=19, n_val=21
# c:\Users\nan\OneDrive\Documentos\ucr\practica profesiona\dengue-model\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\nan\OneDrive\Documentos\ucr\practica profesiona\dengue-model\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\nan\OneDrive\Documentos\ucr\practica profesiona\dengue-model\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# hrf ready for 308
# Threshold tuning failed: The provided estimator makes constant predictions. Therefore, it is impossible to optimize the decision threshold.
# Using best classifier directly without threshold tuning.
#               precision    recall  f1-score   support
#
#            0       0.28      0.71      0.40        17
#            1       0.44      0.11      0.18        35
#
#     accuracy                           0.31        52
#    macro avg       0.36      0.41      0.29        52
# weighted avg       0.39      0.31      0.25        52
#
# Using PredefinedSplit: n_train=39, n_val=49
# hrf ready for 401
#               precision    recall  f1-score   support
#
#            0       0.90      0.55      0.68        49
#            1       0.00      0.00      0.00         3
#
#     accuracy                           0.52        52
#    macro avg       0.45      0.28      0.34        52
# weighted avg       0.85      0.52      0.64        52
#
# Using PredefinedSplit: n_train=22, n_val=29
# hrf ready for 402
#               precision    recall  f1-score   support
#
#            0       0.72      0.59      0.65        39
#            1       0.20      0.31      0.24        13
#
#     accuracy                           0.52        52
#    macro avg       0.46      0.45      0.45        52
# weighted avg       0.59      0.52      0.55        52
#
# Using PredefinedSplit: n_train=25, n_val=25
# hrf ready for 403
#               precision    recall  f1-score   support
#
#            0       0.76      0.68      0.72        41
#            1       0.13      0.18      0.15        11
#
#     accuracy                           0.58        52
#    macro avg       0.45      0.43      0.44        52
# weighted avg       0.62      0.58      0.60        52
#
# Using PredefinedSplit: n_train=39, n_val=23
# hrf ready for 404
# c:\Users\nan\OneDrive\Documentos\ucr\practica profesiona\dengue-model\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\nan\OneDrive\Documentos\ucr\practica profesiona\dengue-model\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\nan\OneDrive\Documentos\ucr\practica profesiona\dengue-model\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98        50
#            1       0.00      0.00      0.00         2
#
#     accuracy                           0.96        52
#    macro avg       0.48      0.50      0.49        52
# weighted avg       0.92      0.96      0.94        52
#
# Using PredefinedSplit: n_train=8, n_val=26
# hrf ready for 405
#               precision    recall  f1-score   support
#
#            0       0.86      0.98      0.92        45
#            1       0.00      0.00      0.00         7
#
#     accuracy                           0.85        52
#    macro avg       0.43      0.49      0.46        52
# weighted avg       0.75      0.85      0.79        52
#
# Using PredefinedSplit: n_train=8, n_val=12
# hrf ready for 406

# %%
for canton in cantons[50:60]: 
    instancia = Model(df, canton)
    X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = instancia.partition()
    instancia.hybrid("hrf", X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.66      0.68      0.67        34
#            1       0.35      0.33      0.34        18
#
#     accuracy                           0.56        52
#    macro avg       0.51      0.50      0.50        52
# weighted avg       0.55      0.56      0.55        52
#
# Using PredefinedSplit: n_train=40, n_val=30
# hrf ready for 407
#               precision    recall  f1-score   support
#
#            0       0.85      0.91      0.88        45
#            1       0.00      0.00      0.00         7
#
#     accuracy                           0.79        52
#    macro avg       0.43      0.46      0.44        52
# weighted avg       0.74      0.79      0.76        52
#
# Using PredefinedSplit: n_train=36, n_val=36
# hrf ready for 408
# Threshold tuning failed: The provided estimator makes constant predictions. Therefore, it is impossible to optimize the decision threshold.
# Using best classifier directly without threshold tuning.
#               precision    recall  f1-score   support
#
#            0       0.79      1.00      0.88        41
#            1       0.00      0.00      0.00        11
#
#     accuracy                           0.79        52
#    macro avg       0.39      0.50      0.44        52
# weighted avg       0.62      0.79      0.70        52
#
# Using PredefinedSplit: n_train=24, n_val=23
# c:\Users\nan\OneDrive\Documentos\ucr\practica profesiona\dengue-model\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\nan\OneDrive\Documentos\ucr\practica profesiona\dengue-model\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\nan\OneDrive\Documentos\ucr\practica profesiona\dengue-model\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# hrf ready for 409
# c:\Users\nan\OneDrive\Documentos\ucr\practica profesiona\dengue-model\.venv\Lib\site-packages\sklearn\model_selection\_search.py:1137: UserWarning: One or more of the test scores are non-finite: [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan]
#   warnings.warn(
#               precision    recall  f1-score   support
#
#            0       0.30      0.40      0.34        20
#            1       0.52      0.41      0.46        32
#
#     accuracy                           0.40        52
#    macro avg       0.41      0.40      0.40        52
# weighted avg       0.43      0.40      0.41        52
#
# Using PredefinedSplit: n_train=52, n_val=166
# hrf ready for 410
#               precision    recall  f1-score   support
#
#            0       0.48      0.82      0.61        17
#            1       0.87      0.57      0.69        35
#
#     accuracy                           0.65        52
#    macro avg       0.68      0.70      0.65        52
# weighted avg       0.74      0.65      0.66        52
#
# Using PredefinedSplit: n_train=34, n_val=35
# hrf ready for 501
#               precision    recall  f1-score   support
#
#            0       0.57      0.50      0.53        34
#            1       0.23      0.28      0.25        18
#
#     accuracy                           0.42        52
#    macro avg       0.40      0.39      0.39        52
# weighted avg       0.45      0.42      0.43        52
#
# Using PredefinedSplit: n_train=42, n_val=71
# hrf ready for 502
#               precision    recall  f1-score   support
#
#            0       0.90      0.45      0.60        20
#            1       0.74      0.97      0.84        32
#
#     accuracy                           0.77        52
#    macro avg       0.82      0.71      0.72        52
# weighted avg       0.80      0.77      0.75        52
#
# Using PredefinedSplit: n_train=49, n_val=102
# hrf ready for 503
#               precision    recall  f1-score   support
#
#            0       0.72      0.62      0.67        29
#            1       0.59      0.70      0.64        23
#
#     accuracy                           0.65        52
#    macro avg       0.66      0.66      0.65        52
# weighted avg       0.66      0.65      0.65        52
#
# Using PredefinedSplit: n_train=25, n_val=64
# hrf ready for 504
#               precision    recall  f1-score   support
#
#            0       0.73      0.55      0.63        20
#            1       0.76      0.88      0.81        32
#
#     accuracy                           0.75        52
#    macro avg       0.75      0.71      0.72        52
# weighted avg       0.75      0.75      0.74        52
#
# Using PredefinedSplit: n_train=39, n_val=87
# hrf ready for 505
#               precision    recall  f1-score   support
#
#            0       0.48      0.41      0.44        29
#            1       0.37      0.43      0.40        23
#
#     accuracy                           0.42        52
#    macro avg       0.43      0.42      0.42        52
# weighted avg       0.43      0.42      0.42        52
#
# Using PredefinedSplit: n_train=42, n_val=67
# hrf ready for 506

# %%
for canton in cantons[60:70]: 
    instancia = Model(df, canton)
    X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = instancia.partition()
    instancia.hybrid("hrf", X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.62      0.74      0.68        31
#            1       0.47      0.33      0.39        21
#
#     accuracy                           0.58        52
#    macro avg       0.54      0.54      0.53        52
# weighted avg       0.56      0.58      0.56        52
#
# Using PredefinedSplit: n_train=38, n_val=56
# hrf ready for 507
#               precision    recall  f1-score   support
#
#            0       0.61      0.62      0.62        32
#            1       0.37      0.35      0.36        20
#
#     accuracy                           0.52        52
#    macro avg       0.49      0.49      0.49        52
# weighted avg       0.51      0.52      0.52        52
#
# Using PredefinedSplit: n_train=32, n_val=33
# hrf ready for 508
# c:\Users\nan\OneDrive\Documentos\ucr\practica profesiona\dengue-model\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\nan\OneDrive\Documentos\ucr\practica profesiona\dengue-model\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\nan\OneDrive\Documentos\ucr\practica profesiona\dengue-model\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
#               precision    recall  f1-score   support
#
#            0       0.83      1.00      0.91        43
#            1       0.00      0.00      0.00         9
#
#     accuracy                           0.83        52
#    macro avg       0.41      0.50      0.45        52
# weighted avg       0.68      0.83      0.75        52
#
# Using PredefinedSplit: n_train=17, n_val=30
# hrf ready for 509
#               precision    recall  f1-score   support
#
#            0       0.54      0.83      0.66        24
#            1       0.73      0.39      0.51        28
#
#     accuracy                           0.60        52
#    macro avg       0.64      0.61      0.58        52
# weighted avg       0.64      0.60      0.58        52
#
# Using PredefinedSplit: n_train=39, n_val=47
# hrf ready for 510
# Threshold tuning failed: The provided estimator makes constant predictions. Therefore, it is impossible to optimize the decision threshold.
# Using best classifier directly without threshold tuning.
#               precision    recall  f1-score   support
#
#            0       0.79      1.00      0.88        41
#            1       0.00      0.00      0.00        11
#
#     accuracy                           0.79        52
#    macro avg       0.39      0.50      0.44        52
# weighted avg       0.62      0.79      0.70        52
#
# Using PredefinedSplit: n_train=8, n_val=33
# c:\Users\nan\OneDrive\Documentos\ucr\practica profesiona\dengue-model\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\nan\OneDrive\Documentos\ucr\practica profesiona\dengue-model\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\nan\OneDrive\Documentos\ucr\practica profesiona\dengue-model\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# hrf ready for 511
# c:\Users\nan\OneDrive\Documentos\ucr\practica profesiona\dengue-model\.venv\Lib\site-packages\sklearn\model_selection\_search.py:1137: UserWarning: One or more of the test scores are non-finite: [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan]
#   warnings.warn(
#               precision    recall  f1-score   support
#
#            0       0.35      0.90      0.50        10
#            1       0.96      0.60      0.74        42
#
#     accuracy                           0.65        52
#    macro avg       0.65      0.75      0.62        52
# weighted avg       0.84      0.65      0.69        52
#
# Using PredefinedSplit: n_train=52, n_val=176
# hrf ready for 601
#               precision    recall  f1-score   support
#
#            0       0.17      0.25      0.20         4
#            1       0.93      0.90      0.91        48
#
#     accuracy                           0.85        52
#    macro avg       0.55      0.57      0.56        52
# weighted avg       0.88      0.85      0.86        52
#
# Using PredefinedSplit: n_train=48, n_val=97
# hrf ready for 602
#               precision    recall  f1-score   support
#
#            0       0.67      0.72      0.69        36
#            1       0.23      0.19      0.21        16
#
#     accuracy                           0.56        52
#    macro avg       0.45      0.45      0.45        52
# weighted avg       0.53      0.56      0.54        52
#
# Using PredefinedSplit: n_train=49, n_val=92
# hrf ready for 603
#               precision    recall  f1-score   support
#
#            0       0.82      0.82      0.82        28
#            1       0.79      0.79      0.79        24
#
#     accuracy                           0.81        52
#    macro avg       0.81      0.81      0.81        52
# weighted avg       0.81      0.81      0.81        52
#
# Using PredefinedSplit: n_train=41, n_val=42
# hrf ready for 604
#               precision    recall  f1-score   support
#
#            0       0.19      0.45      0.27        11
#            1       0.77      0.49      0.60        41
#
#     accuracy                           0.48        52
#    macro avg       0.48      0.47      0.43        52
# weighted avg       0.65      0.48      0.53        52
#
# Using PredefinedSplit: n_train=46, n_val=79
# hrf ready for 605

# %%
for canton in cantons[70:82]: 
    instancia = Model(df, canton)
    X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = instancia.partition()
    instancia.hybrid("hrf", X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.59      0.70        46
#            1       0.10      0.33      0.15         6
#
#     accuracy                           0.56        52
#    macro avg       0.48      0.46      0.42        52
# weighted avg       0.78      0.56      0.64        52
#
# Using PredefinedSplit: n_train=38, n_val=82
# hrf ready for 606
#               precision    recall  f1-score   support
#
#            0       0.69      0.75      0.72        32
#            1       0.53      0.45      0.49        20
#
#     accuracy                           0.63        52
#    macro avg       0.61      0.60      0.60        52
# weighted avg       0.63      0.63      0.63        52
#
# Using PredefinedSplit: n_train=45, n_val=66
# hrf ready for 607
#               precision    recall  f1-score   support
#
#            0       0.82      0.84      0.83        44
#            1       0.00      0.00      0.00         8
#
#     accuracy                           0.71        52
#    macro avg       0.41      0.42      0.42        52
# weighted avg       0.70      0.71      0.70        52
#
# Using PredefinedSplit: n_train=17, n_val=20
# hrf ready for 608
#               precision    recall  f1-score   support
#
#            0       0.62      0.71      0.67        21
#            1       0.79      0.71      0.75        31
#
#     accuracy                           0.71        52
#    macro avg       0.71      0.71      0.71        52
# weighted avg       0.72      0.71      0.71        52
#
# Using PredefinedSplit: n_train=33, n_val=84
# hrf ready for 609
#               precision    recall  f1-score   support
#
#            0       0.49      0.88      0.63        24
#            1       0.67      0.21      0.32        28
#
#     accuracy                           0.52        52
#    macro avg       0.58      0.54      0.48        52
# weighted avg       0.58      0.52      0.46        52
#
# Using PredefinedSplit: n_train=50, n_val=125
# hrf ready for 610
#               precision    recall  f1-score   support
#
#            0       0.76      0.82      0.79        34
#            1       0.60      0.50      0.55        18
#
#     accuracy                           0.71        52
#    macro avg       0.68      0.66      0.67        52
# weighted avg       0.70      0.71      0.70        52
#
# Using PredefinedSplit: n_train=43, n_val=65
# hrf ready for 611
#               precision    recall  f1-score   support
#
#            0       0.28      0.62      0.38        13
#            1       0.78      0.46      0.58        39
#
#     accuracy                           0.50        52
#    macro avg       0.53      0.54      0.48        52
# weighted avg       0.66      0.50      0.53        52
#
# Using PredefinedSplit: n_train=42, n_val=161
# hrf ready for 701
#               precision    recall  f1-score   support
#
#            0       0.43      0.19      0.26        16
#            1       0.71      0.89      0.79        36
#
#     accuracy                           0.67        52
#    macro avg       0.57      0.54      0.53        52
# weighted avg       0.62      0.67      0.63        52
#
# Using PredefinedSplit: n_train=49, n_val=193
# hrf ready for 702
# c:\Users\nan\OneDrive\Documentos\ucr\practica profesiona\dengue-model\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\nan\OneDrive\Documentos\ucr\practica profesiona\dengue-model\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\nan\OneDrive\Documentos\ucr\practica profesiona\dengue-model\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
#               precision    recall  f1-score   support
#
#            0       0.62      1.00      0.76        32
#            1       0.00      0.00      0.00        20
#
#     accuracy                           0.62        52
#    macro avg       0.31      0.50      0.38        52
# weighted avg       0.38      0.62      0.47        52
#
# Using PredefinedSplit: n_train=48, n_val=181
# hrf ready for 703
#               precision    recall  f1-score   support
#
#            0       0.64      0.94      0.76        31
#            1       0.71      0.24      0.36        21
#
#     accuracy                           0.65        52
#    macro avg       0.68      0.59      0.56        52
# weighted avg       0.67      0.65      0.60        52
#
# Using PredefinedSplit: n_train=39, n_val=194
# hrf ready for 704
#               precision    recall  f1-score   support
#
#            0       0.60      0.81      0.68        31
#            1       0.40      0.19      0.26        21
#
#     accuracy                           0.56        52
#    macro avg       0.50      0.50      0.47        52
# weighted avg       0.52      0.56      0.51        52
#
# Using PredefinedSplit: n_train=45, n_val=147
# hrf ready for 705
#               precision    recall  f1-score   support
#
#            0       0.70      0.66      0.68        32
#            1       0.50      0.55      0.52        20
#
#     accuracy                           0.62        52
#    macro avg       0.60      0.60      0.60        52
# weighted avg       0.62      0.62      0.62        52
#
# Using PredefinedSplit: n_train=48, n_val=193
# hrf ready for 706

# %% [markdown]
# ## Save metrics

# %%
cod_cant_hrf = []
nrmse_hrf = []

for canton in cantons: 
    instancia = Model(df, canton)
    cant_temp, nrmse_temp = instancia.calculate_nrmse("hrf")
    cod_cant_hrf.append(canton)
    nrmse_hrf.append(nrmse_temp)

nrmse_hrf = pd.DataFrame({"canton": cod_cant_hrf,
                         "nrmse": nrmse_hrf})

nrmse_hrf.to_csv("../../data/model_results/metrics/hrf.csv")
# Out:
# c:\Users\nan\OneDrive\Documentos\ucr\practica profesiona\dengue-model\models\model_scripts\../../models\model_rr.py:548: RuntimeWarning: invalid value encountered in scalar divide
#   nrmse = rmse / np.mean(results["actual"])

# %% [markdown]
# ## Best

# %%
nrmse_hrf = pd.read_csv("../../data/model_results/metrics/hrf.csv")

nrmse_hrf = nrmse_hrf[np.isfinite(nrmse_hrf)] # Prevent using cantons with an NRMSE undefined because their mean cases is 0
nrmse_hrf = nrmse_hrf[nrmse_hrf["nrmse"].notnull()] # Prevent using cantons with an NRMSE undefined because their mean cases is 0

# %%
best_hrf = Model(df, cantons[nrmse_hrf["nrmse"].idxmin()])

# %% [markdown]
# ### Plot results

# %%
X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = best_hrf.partition()
y_pred_point, lower_bound, upper_bound = best_hrf.prediction_intervals(X_combined, y_combined, X_test, epsilon, "hrf", repeats = 100)
best_hrf.serie_temp_canton("hrf", y_pred_point, lower_bound, upper_bound)

# %% [markdown]
# ### Confidence intervals for NRMSE

# %%
print(f"Best canton NRMSE for HRF: {round(nrmse_hrf.iloc[nrmse_hrf["nrmse"].idxmin(), 2], 4)}")
# Out:
# Best canton NRMSE for HRF: 0.3494

# %%
X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = best_hrf.partition()
best_hrf.confint_nrmse("hrf", X_combined, y_combined, X_test, y_test, epsilon, n_bootstraps = 100)
# Out:
# Only one class present in test set for classification. Skipping classification step.
# point estimate: 0.47
# lower bound: 0.34, upper bound: 0.91

# %% [markdown]
# ### Feature importance

# %%
X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = best_hrf.partition()
best_hrf.var_importance(X_test, y_test, "hrf", repeats = 100, var = "RR")
# Out:
#                  Feature   imp_hrf   std_hrf
# 0               rr_lag_1  0.038212  0.015581
# 1               rr_lag_2  0.003276  0.013216
# 2             ndvi_lag_4  0.001485  0.000467
# 3             ndvi_lag_3  0.001290  0.000874
# 4               rr_lag_3  0.000886  0.000652
# ..                   ...       ...       ...
# 101  precip_median_lag_1 -0.000701  0.000506
# 102   precip_total_lag_1 -0.000748  0.000398
# 103  precip_median_lag_3 -0.000782  0.000548
# 104     precip_max_lag_1 -0.002346  0.000988
# 105           ndvi_lag_1 -0.004499  0.002723
#
# [106 rows x 3 columns]
#                  Feature   imp_hrf   std_hrf
# 0               rr_lag_1  0.038212  0.015581
# 1               rr_lag_2  0.003276  0.013216
# 2             ndvi_lag_4  0.001485  0.000467
# 3             ndvi_lag_3  0.001290  0.000874
# 4               rr_lag_3  0.000886  0.000652
# ..                   ...       ...       ...
# 101  precip_median_lag_1 -0.000701  0.000506
# 102   precip_total_lag_1 -0.000748  0.000398
# 103  precip_median_lag_3 -0.000782  0.000548
# 104     precip_max_lag_1 -0.002346  0.000988
# 105           ndvi_lag_1 -0.004499  0.002723
#
# [106 rows x 3 columns]

# %% [markdown]
# ### Feature selection

# %%
X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = best_hrf.partition()
best_hrf.rfecv_selection("hrf", X_combined, y_combined, X_test, y_test, pds, repeats = 100, var = "RR")
# Out:
# Optimal number of features for RR and hrf: 5
# Selected features: ['rr_lag_4', 'rr_lag_3', 'rr_lag_2', 'rr_lag_1', 'ndvi_lag_1']
# New NRMSE with selected features: 0.3113

# %% [markdown]
# ## Worst

# %%
nrmse_hrf = pd.read_csv("../../data/model_results/metrics/hrf.csv")

nrmse_hrf = nrmse_hrf[np.isfinite(nrmse_hrf)] # Prevent using cantons with an NRMSE undefined because their mean cases is 0
nrmse_hrf = nrmse_hrf[nrmse_hrf["nrmse"].notnull()] # Prevent using cantons with an NRMSE undefined because their mean cases is 0

# %%
worst_hrf = Model(df, cantons[nrmse_hrf["nrmse"].idxmax()])

# %% [markdown]
# ### Plot results

# %%
X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = worst_hrf.partition()
y_pred_point, lower_bound, upper_bound = worst_hrf.prediction_intervals(X_combined, y_combined, X_test, epsilon, "hrf", repeats = 100)
worst_hrf.serie_temp_canton("hrf", y_pred_point, lower_bound, upper_bound)

# %% [markdown]
# ### Confidence intervals for NRMSE

# %%
print(f"Worst canton NRMSE for HRF: {round(nrmse_hrf.iloc[nrmse_hrf["nrmse"].idxmax(), 2], 4)}")
# Out:
# Worst canton NRMSE for HRF: 0.6606

# %%
X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = worst_hrf.partition()
worst_hrf.confint_nrmse("hrf", X_combined, y_combined, X_test, y_test, epsilon, n_bootstraps = 100)
# Out:
# point estimate: 7.21
# lower bound: 7.21, upper bound: 7.21

# %% [markdown]
# ### Feature importance

# %%
X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = worst_hrf.partition()
worst_hrf.var_importance(X_test, y_test, "hrf", repeats = 100, var = "RR")
# Out:
#               Feature  imp_hrf  std_hrf
# 0          nino34ssta      0.0      0.0
# 1            rr_lag_4      0.0      0.0
# 2            rr_lag_3      0.0      0.0
# 3            rr_lag_2      0.0      0.0
# 4            rr_lag_1      0.0      0.0
# ..                ...      ...      ...
# 101  precip_min_lag_4      0.0      0.0
# 102  precip_min_lag_3      0.0      0.0
# 103  precip_min_lag_2      0.0      0.0
# 104  precip_min_lag_1      0.0      0.0
# 105             urb_2      0.0      0.0
#
# [106 rows x 3 columns]
#               Feature  imp_hrf  std_hrf
# 0          nino34ssta      0.0      0.0
# 1            rr_lag_4      0.0      0.0
# 2            rr_lag_3      0.0      0.0
# 3            rr_lag_2      0.0      0.0
# 4            rr_lag_1      0.0      0.0
# ..                ...      ...      ...
# 101  precip_min_lag_4      0.0      0.0
# 102  precip_min_lag_3      0.0      0.0
# 103  precip_min_lag_2      0.0      0.0
# 104  precip_min_lag_1      0.0      0.0
# 105             urb_2      0.0      0.0
#
# [106 rows x 3 columns]

# %% [markdown]
# ### Feature selection

# %%
X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = worst_hrf.partition()
worst_hrf.rfecv_selection("hrf", X_combined, y_combined, X_test, y_test, pds, repeats = 100, var = "RR")
# Out:
# Optimal number of features for RR and hrf: 6
# Selected features: ['ndvi_lag_1', 'temp_prom_lag_2', 'empleo_lag_4', 'empleo_lag_3', 'empleo_lag_2', 'precip_max_lag_3']
# New NRMSE with selected features: -0.3597

# %% [markdown]
# # HXGB

# %% [markdown]
# ## Fit models

# %%
for canton in cantons[0:10]: 
    instancia = Model(df, canton)
    X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = instancia.partition()
    instancia.hybrid("hxgb", X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon)
# Out:
# WARNING: Test set only contains one label: 1
# Only one class present in test set for classification. Skipping classification step.
# Using PredefinedSplit: n_train=52, n_val=149
# hxgb ready for 101
#               precision    recall  f1-score   support
#
#            0       0.55      0.42      0.48        26
#            1       0.53      0.65      0.59        26
#
#     accuracy                           0.54        52
#    macro avg       0.54      0.54      0.53        52
# weighted avg       0.54      0.54      0.53        52
#
# Using PredefinedSplit: n_train=37, n_val=32
# hxgb ready for 102
# c:\Users\nan\OneDrive\Documentos\ucr\practica profesiona\dengue-model\.venv\Lib\site-packages\sklearn\model_selection\_search.py:1137: UserWarning: One or more of the test scores are non-finite: [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan]
#   warnings.warn(
#               precision    recall  f1-score   support
#
#            0       0.28      0.85      0.42        13
#            1       0.83      0.26      0.39        39
#
#     accuracy                           0.40        52
#    macro avg       0.55      0.55      0.40        52
# weighted avg       0.69      0.40      0.40        52
#
# Using PredefinedSplit: n_train=52, n_val=71
# hxgb ready for 103
#               precision    recall  f1-score   support
#
#            0       0.75      0.42      0.54        43
#            1       0.11      0.33      0.16         9
#
#     accuracy                           0.40        52
#    macro avg       0.43      0.38      0.35        52
# weighted avg       0.64      0.40      0.47        52
#
# Using PredefinedSplit: n_train=41, n_val=41
# hxgb ready for 104
#               precision    recall  f1-score   support
#
#            0       0.94      0.65      0.77        49
#            1       0.06      0.33      0.10         3
#
#     accuracy                           0.63        52
#    macro avg       0.50      0.49      0.43        52
# weighted avg       0.89      0.63      0.73        52
#
# Using PredefinedSplit: n_train=1, n_val=11
# hxgb ready for 105
#               precision    recall  f1-score   support
#
#            0       0.64      0.64      0.64        33
#            1       0.37      0.37      0.37        19
#
#     accuracy                           0.54        52
#    macro avg       0.50      0.50      0.50        52
# weighted avg       0.54      0.54      0.54        52
#
# Using PredefinedSplit: n_train=43, n_val=32
# hxgb ready for 106
#               precision    recall  f1-score   support
#
#            0       0.71      0.76      0.73        38
#            1       0.18      0.14      0.16        14
#
#     accuracy                           0.60        52
#    macro avg       0.44      0.45      0.45        52
# weighted avg       0.57      0.60      0.58        52
#
# Using PredefinedSplit: n_train=48, n_val=49
# hxgb ready for 107
#               precision    recall  f1-score   support
#
#            0       0.45      0.38      0.42        26
#            1       0.47      0.54      0.50        26
#
#     accuracy                           0.46        52
#    macro avg       0.46      0.46      0.46        52
# weighted avg       0.46      0.46      0.46        52
#
# Using PredefinedSplit: n_train=35, n_val=39
# hxgb ready for 108
# c:\Users\nan\OneDrive\Documentos\ucr\practica profesiona\dengue-model\.venv\Lib\site-packages\sklearn\model_selection\_search.py:1137: UserWarning: One or more of the test scores are non-finite: [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan]
#   warnings.warn(
#               precision    recall  f1-score   support
#
#            0       0.15      0.88      0.25         8
#            1       0.75      0.07      0.12        44
#
#     accuracy                           0.19        52
#    macro avg       0.45      0.47      0.19        52
# weighted avg       0.66      0.19      0.14        52
#
# Using PredefinedSplit: n_train=52, n_val=92
# hxgb ready for 109
# c:\Users\nan\OneDrive\Documentos\ucr\practica profesiona\dengue-model\.venv\Lib\site-packages\sklearn\model_selection\_search.py:1137: UserWarning: One or more of the test scores are non-finite: [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan]
#   warnings.warn(
# c:\Users\nan\OneDrive\Documentos\ucr\practica profesiona\dengue-model\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\nan\OneDrive\Documentos\ucr\practica profesiona\dengue-model\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\nan\OneDrive\Documentos\ucr\practica profesiona\dengue-model\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         5
#            1       0.90      1.00      0.95        47
#
#     accuracy                           0.90        52
#    macro avg       0.45      0.50      0.47        52
# weighted avg       0.82      0.90      0.86        52
#
# Using PredefinedSplit: n_train=52, n_val=54
# hxgb ready for 110

# %%
for canton in cantons[10:20]: 
    instancia = Model(df, canton)
    X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = instancia.partition()
    instancia.hybrid("hxgb", X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon)
# Out:
# c:\Users\nan\OneDrive\Documentos\ucr\practica profesiona\dengue-model\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\nan\OneDrive\Documentos\ucr\practica profesiona\dengue-model\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\nan\OneDrive\Documentos\ucr\practica profesiona\dengue-model\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        43
#            1       0.17      1.00      0.30         9
#
#     accuracy                           0.17        52
#    macro avg       0.09      0.50      0.15        52
# weighted avg       0.03      0.17      0.05        52
#
# Using PredefinedSplit: n_train=17, n_val=24
# hxgb ready for 111
# c:\Users\nan\OneDrive\Documentos\ucr\practica profesiona\dengue-model\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\nan\OneDrive\Documentos\ucr\practica profesiona\dengue-model\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\nan\OneDrive\Documentos\ucr\practica profesiona\dengue-model\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
#               precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92        44
#            1       0.00      0.00      0.00         8
#
#     accuracy                           0.85        52
#    macro avg       0.42      0.50      0.46        52
# weighted avg       0.72      0.85      0.78        52
#
# Using PredefinedSplit: n_train=22, n_val=25
# hxgb ready for 112
#               precision    recall  f1-score   support
#
#            0       0.45      0.68      0.54        25
#            1       0.43      0.22      0.29        27
#
#     accuracy                           0.44        52
#    macro avg       0.44      0.45      0.42        52
# weighted avg       0.44      0.44      0.41        52
#
# Using PredefinedSplit: n_train=45, n_val=51
# hxgb ready for 113
#               precision    recall  f1-score   support
#
#            0       0.79      0.66      0.72        41
#            1       0.22      0.36      0.28        11
#
#     accuracy                           0.60        52
#    macro avg       0.51      0.51      0.50        52
# weighted avg       0.67      0.60      0.63        52
#
# Using PredefinedSplit: n_train=19, n_val=27
# hxgb ready for 114
#               precision    recall  f1-score   support
#
#            0       0.75      0.63      0.68        43
#            1       0.00      0.00      0.00         9
#
#     accuracy                           0.52        52
#    macro avg       0.38      0.31      0.34        52
# weighted avg       0.62      0.52      0.57        52
#
# Using PredefinedSplit: n_train=32, n_val=33
# hxgb ready for 115
#               precision    recall  f1-score   support
#
#            0       1.00      0.67      0.80        51
#            1       0.06      1.00      0.11         1
#
#     accuracy                           0.67        52
#    macro avg       0.53      0.83      0.45        52
# weighted avg       0.98      0.67      0.79        52
#
# Using PredefinedSplit: n_train=16, n_val=28
# hxgb ready for 116
# WARNING: Test set only contains one label: 0
# Only one class present in test set for classification. Skipping classification step.
# WARNING: No positive cases in some set (n_train=0, n_val=6). Using cv=5.
# hxgb ready for 117
# c:\Users\nan\OneDrive\Documentos\ucr\practica profesiona\dengue-model\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\nan\OneDrive\Documentos\ucr\practica profesiona\dengue-model\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\nan\OneDrive\Documentos\ucr\practica profesiona\dengue-model\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        27
#            1       0.48      1.00      0.65        25
#
#     accuracy                           0.48        52
#    macro avg       0.24      0.50      0.32        52
# weighted avg       0.23      0.48      0.31        52
#
# Using PredefinedSplit: n_train=41, n_val=34
# hxgb ready for 118
#               precision    recall  f1-score   support
#
#            0       0.67      0.08      0.15        24
#            1       0.55      0.96      0.70        28
#
#     accuracy                           0.56        52
#    macro avg       0.61      0.52      0.42        52
# weighted avg       0.60      0.56      0.45        52
#
# Using PredefinedSplit: n_train=45, n_val=148
# hxgb ready for 119
#               precision    recall  f1-score   support
#
#            0       0.96      0.47      0.63        51
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.46        52
#    macro avg       0.48      0.24      0.32        52
# weighted avg       0.94      0.46      0.62        52
#
# Using PredefinedSplit: n_train=3, n_val=7
# hxgb ready for 120

# %%
for canton in cantons[20:30]: 
    instancia = Model(df, canton)
    X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = instancia.partition()
    instancia.hybrid("hxgb", X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon)
# Out:
# WARNING: Test set only contains one label: 1
# Only one class present in test set for classification. Skipping classification step.
# Using PredefinedSplit: n_train=52, n_val=151
# hxgb ready for 201
#               precision    recall  f1-score   support
#
#            0       0.76      0.65      0.70        34
#            1       0.48      0.61      0.54        18
#
#     accuracy                           0.63        52
#    macro avg       0.62      0.63      0.62        52
# weighted avg       0.66      0.63      0.64        52
#
# Using PredefinedSplit: n_train=38, n_val=39
# hxgb ready for -202
#               precision    recall  f1-score   support
#
#            0       0.70      0.84      0.77        37
#            1       0.25      0.13      0.17        15
#
#     accuracy                           0.63        52
#    macro avg       0.48      0.49      0.47        52
# weighted avg       0.57      0.63      0.59        52
#
# Using PredefinedSplit: n_train=50, n_val=58
# hxgb ready for 203
#               precision    recall  f1-score   support
#
#            0       0.93      0.53      0.68        47
#            1       0.12      0.60      0.20         5
#
#     accuracy                           0.54        52
#    macro avg       0.52      0.57      0.44        52
# weighted avg       0.85      0.54      0.63        52
#
# Using PredefinedSplit: n_train=29, n_val=41
# hxgb ready for 204
# c:\Users\nan\OneDrive\Documentos\ucr\practica profesiona\dengue-model\.venv\Lib\site-packages\sklearn\model_selection\_search.py:1137: UserWarning: One or more of the test scores are non-finite: [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan]
#   warnings.warn(
#               precision    recall  f1-score   support
#
#            0       0.54      0.84      0.66        25
#            1       0.69      0.33      0.45        27
#
#     accuracy                           0.58        52
#    macro avg       0.62      0.59      0.55        52
# weighted avg       0.62      0.58      0.55        52
#
# Using PredefinedSplit: n_train=52, n_val=99
# hxgb ready for 205
#               precision    recall  f1-score   support
#
#            0       0.69      0.81      0.74        36
#            1       0.30      0.19      0.23        16
#
#     accuracy                           0.62        52
#    macro avg       0.50      0.50      0.49        52
# weighted avg       0.57      0.62      0.59        52
#
# Using PredefinedSplit: n_train=26, n_val=56
# hxgb ready for 206
#               precision    recall  f1-score   support
#
#            0       0.80      0.88      0.84        42
#            1       0.17      0.10      0.12        10
#
#     accuracy                           0.73        52
#    macro avg       0.49      0.49      0.48        52
# weighted avg       0.68      0.73      0.70        52
#
# Using PredefinedSplit: n_train=49, n_val=21
# hxgb ready for 207
#               precision    recall  f1-score   support
#
#            0       0.83      0.59      0.69        41
#            1       0.26      0.55      0.35        11
#
#     accuracy                           0.58        52
#    macro avg       0.54      0.57      0.52        52
# weighted avg       0.71      0.58      0.62        52
#
# Using PredefinedSplit: n_train=40, n_val=58
# hxgb ready for 208
#               precision    recall  f1-score   support
#
#            0       0.63      0.71      0.67        34
#            1       0.29      0.22      0.25        18
#
#     accuracy                           0.54        52
#    macro avg       0.46      0.46      0.46        52
# weighted avg       0.51      0.54      0.52        52
#
# Using PredefinedSplit: n_train=44, n_val=121
# hxgb ready for 209
# c:\Users\nan\OneDrive\Documentos\ucr\practica profesiona\dengue-model\.venv\Lib\site-packages\sklearn\model_selection\_search.py:1137: UserWarning: One or more of the test scores are non-finite: [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan]
#   warnings.warn(
# c:\Users\nan\OneDrive\Documentos\ucr\practica profesiona\dengue-model\.venv\Lib\site-packages\sklearn\model_selection\_split.py:813: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# Threshold tuning failed: The provided estimator makes constant predictions. Therefore, it is impossible to optimize the decision threshold.
# Using best classifier directly without threshold tuning.
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        10
#            1       0.81      1.00      0.89        42
#
#     accuracy                           0.81        52
#    macro avg       0.40      0.50      0.45        52
# weighted avg       0.65      0.81      0.72        52
#
# Using PredefinedSplit: n_train=52, n_val=198
# c:\Users\nan\OneDrive\Documentos\ucr\practica profesiona\dengue-model\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\nan\OneDrive\Documentos\ucr\practica profesiona\dengue-model\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\nan\OneDrive\Documentos\ucr\practica profesiona\dengue-model\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# hxgb ready for 210

# %%
for canton in cantons[30:40]: 
    instancia = Model(df, canton)
    X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = instancia.partition()
    instancia.hybrid("hxgb", X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon)
# Out:
# c:\Users\nan\OneDrive\Documentos\ucr\practica profesiona\dengue-model\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\nan\OneDrive\Documentos\ucr\practica profesiona\dengue-model\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\nan\OneDrive\Documentos\ucr\practica profesiona\dengue-model\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        51
#            1       0.02      1.00      0.04         1
#
#     accuracy                           0.02        52
#    macro avg       0.01      0.50      0.02        52
# weighted avg       0.00      0.02      0.00        52
#
# Using PredefinedSplit: n_train=1, n_val=4
# hxgb ready for 211
#               precision    recall  f1-score   support
#
#            0       0.98      0.78      0.87        51
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.77        52
#    macro avg       0.49      0.39      0.43        52
# weighted avg       0.96      0.77      0.85        52
#
# Using PredefinedSplit: n_train=27, n_val=17
# hxgb ready for 212
#               precision    recall  f1-score   support
#
#            0       0.82      0.82      0.82        44
#            1       0.00      0.00      0.00         8
#
#     accuracy                           0.69        52
#    macro avg       0.41      0.41      0.41        52
# weighted avg       0.69      0.69      0.69        52
#
# Using PredefinedSplit: n_train=17, n_val=41
# hxgb ready for 213
#               precision    recall  f1-score   support
#
#            0       0.79      0.82      0.81        28
#            1       0.78      0.75      0.77        24
#
#     accuracy                           0.79        52
#    macro avg       0.79      0.79      0.79        52
# weighted avg       0.79      0.79      0.79        52
#
# Using PredefinedSplit: n_train=39, n_val=93
# hxgb ready for 214
# c:\Users\nan\OneDrive\Documentos\ucr\practica profesiona\dengue-model\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\nan\OneDrive\Documentos\ucr\practica profesiona\dengue-model\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\nan\OneDrive\Documentos\ucr\practica profesiona\dengue-model\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
#               precision    recall  f1-score   support
#
#            0       0.83      1.00      0.91        43
#            1       0.00      0.00      0.00         9
#
#     accuracy                           0.83        52
#    macro avg       0.41      0.50      0.45        52
# weighted avg       0.68      0.83      0.75        52
#
# Using PredefinedSplit: n_train=18, n_val=24
# hxgb ready for 215
#               precision    recall  f1-score   support
#
#            0       0.76      0.92      0.83        38
#            1       0.50      0.21      0.30        14
#
#     accuracy                           0.73        52
#    macro avg       0.63      0.57      0.57        52
# weighted avg       0.69      0.73      0.69        52
#
# Using PredefinedSplit: n_train=48, n_val=82
# hxgb ready for 216
#               precision    recall  f1-score   support
#
#            0       0.55      0.47      0.51        36
#            1       0.10      0.12      0.11        16
#
#     accuracy                           0.37        52
#    macro avg       0.32      0.30      0.31        52
# weighted avg       0.41      0.37      0.38        52
#
# Using PredefinedSplit: n_train=27, n_val=37
# hxgb ready for 301
#               precision    recall  f1-score   support
#
#            0       0.83      0.46      0.59        41
#            1       0.24      0.64      0.35        11
#
#     accuracy                           0.50        52
#    macro avg       0.53      0.55      0.47        52
# weighted avg       0.70      0.50      0.54        52
#
# Using PredefinedSplit: n_train=30, n_val=22
# hxgb ready for 302
#               precision    recall  f1-score   support
#
#            0       0.61      0.44      0.51        25
#            1       0.59      0.74      0.66        27
#
#     accuracy                           0.60        52
#    macro avg       0.60      0.59      0.58        52
# weighted avg       0.60      0.60      0.59        52
#
# Using PredefinedSplit: n_train=38, n_val=47
# hxgb ready for 303
#               precision    recall  f1-score   support
#
#            0       0.85      0.73      0.79        45
#            1       0.08      0.14      0.10         7
#
#     accuracy                           0.65        52
#    macro avg       0.46      0.44      0.44        52
# weighted avg       0.74      0.65      0.69        52
#
# Using PredefinedSplit: n_train=49, n_val=122
# hxgb ready for 304

# %%
for canton in cantons[40:50]: 
    instancia = Model(df, canton)
    X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = instancia.partition()
    instancia.hybrid("hxgb", X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon)
# Out:
# c:\Users\nan\OneDrive\Documentos\ucr\practica profesiona\dengue-model\.venv\Lib\site-packages\sklearn\model_selection\_search.py:1137: UserWarning: One or more of the test scores are non-finite: [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan]
#   warnings.warn(
#               precision    recall  f1-score   support
#
#            0       0.62      0.94      0.75        33
#            1       0.00      0.00      0.00        19
#
#     accuracy                           0.60        52
#    macro avg       0.31      0.47      0.37        52
# weighted avg       0.39      0.60      0.47        52
#
# Using PredefinedSplit: n_train=52, n_val=167
# hxgb ready for 305
#               precision    recall  f1-score   support
#
#            0       0.82      0.50      0.62        46
#            1       0.04      0.17      0.07         6
#
#     accuracy                           0.46        52
#    macro avg       0.43      0.33      0.34        52
# weighted avg       0.73      0.46      0.56        52
#
# Using PredefinedSplit: n_train=3, n_val=9
# hxgb ready for 306
# c:\Users\nan\OneDrive\Documentos\ucr\practica profesiona\dengue-model\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\nan\OneDrive\Documentos\ucr\practica profesiona\dengue-model\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\nan\OneDrive\Documentos\ucr\practica profesiona\dengue-model\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        45
#            1       0.13      1.00      0.24         7
#
#     accuracy                           0.13        52
#    macro avg       0.07      0.50      0.12        52
# weighted avg       0.02      0.13      0.03        52
#
# Using PredefinedSplit: n_train=9, n_val=8
# hxgb ready for 307
#               precision    recall  f1-score   support
#
#            0       0.73      0.40      0.52        40
#            1       0.20      0.50      0.29        12
#
#     accuracy                           0.42        52
#    macro avg       0.46      0.45      0.40        52
# weighted avg       0.61      0.42      0.46        52
#
# Using PredefinedSplit: n_train=19, n_val=21
# hxgb ready for 308
#               precision    recall  f1-score   support
#
#            0       0.31      0.53      0.39        17
#            1       0.65      0.43      0.52        35
#
#     accuracy                           0.46        52
#    macro avg       0.48      0.48      0.45        52
# weighted avg       0.54      0.46      0.48        52
#
# Using PredefinedSplit: n_train=39, n_val=49
# hxgb ready for 401
#               precision    recall  f1-score   support
#
#            0       0.94      0.67      0.79        49
#            1       0.06      0.33      0.10         3
#
#     accuracy                           0.65        52
#    macro avg       0.50      0.50      0.44        52
# weighted avg       0.89      0.65      0.75        52
#
# Using PredefinedSplit: n_train=22, n_val=29
# hxgb ready for 402
#               precision    recall  f1-score   support
#
#            0       0.73      0.49      0.58        39
#            1       0.23      0.46      0.31        13
#
#     accuracy                           0.48        52
#    macro avg       0.48      0.47      0.45        52
# weighted avg       0.61      0.48      0.52        52
#
# Using PredefinedSplit: n_train=25, n_val=25
# hxgb ready for 403
#               precision    recall  f1-score   support
#
#            0       0.90      0.66      0.76        41
#            1       0.36      0.73      0.48        11
#
#     accuracy                           0.67        52
#    macro avg       0.63      0.69      0.62        52
# weighted avg       0.79      0.67      0.70        52
#
# Using PredefinedSplit: n_train=39, n_val=23
# hxgb ready for 404
#               precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97        50
#            1       0.00      0.00      0.00         2
#
#     accuracy                           0.94        52
#    macro avg       0.48      0.49      0.49        52
# weighted avg       0.92      0.94      0.93        52
#
# Using PredefinedSplit: n_train=8, n_val=26
# hxgb ready for 405
# c:\Users\nan\OneDrive\Documentos\ucr\practica profesiona\dengue-model\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\nan\OneDrive\Documentos\ucr\practica profesiona\dengue-model\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\nan\OneDrive\Documentos\ucr\practica profesiona\dengue-model\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93        45
#            1       0.00      0.00      0.00         7
#
#     accuracy                           0.87        52
#    macro avg       0.43      0.50      0.46        52
# weighted avg       0.75      0.87      0.80        52
#
# Using PredefinedSplit: n_train=8, n_val=12
# hxgb ready for 406

# %%
for canton in cantons[50:60]: 
    instancia = Model(df, canton)
    X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = instancia.partition()
    instancia.hybrid("hxgb", X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.73      0.56      0.63        34
#            1       0.42      0.61      0.50        18
#
#     accuracy                           0.58        52
#    macro avg       0.58      0.58      0.57        52
# weighted avg       0.62      0.58      0.59        52
#
# Using PredefinedSplit: n_train=40, n_val=30
# hxgb ready for 407
#               precision    recall  f1-score   support
#
#            0       0.86      0.53      0.66        45
#            1       0.12      0.43      0.19         7
#
#     accuracy                           0.52        52
#    macro avg       0.49      0.48      0.43        52
# weighted avg       0.76      0.52      0.60        52
#
# Using PredefinedSplit: n_train=36, n_val=36
# hxgb ready for 408
#               precision    recall  f1-score   support
#
#            0       0.77      0.41      0.54        41
#            1       0.20      0.55      0.29        11
#
#     accuracy                           0.44        52
#    macro avg       0.49      0.48      0.42        52
# weighted avg       0.65      0.44      0.49        52
#
# Using PredefinedSplit: n_train=24, n_val=23
# hxgb ready for 409
# c:\Users\nan\OneDrive\Documentos\ucr\practica profesiona\dengue-model\.venv\Lib\site-packages\sklearn\model_selection\_search.py:1137: UserWarning: One or more of the test scores are non-finite: [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan]
#   warnings.warn(
#               precision    recall  f1-score   support
#
#            0       0.33      0.35      0.34        20
#            1       0.58      0.56      0.57        32
#
#     accuracy                           0.48        52
#    macro avg       0.46      0.46      0.46        52
# weighted avg       0.49      0.48      0.48        52
#
# Using PredefinedSplit: n_train=52, n_val=166
# hxgb ready for 410
#               precision    recall  f1-score   support
#
#            0       0.31      0.59      0.41        17
#            1       0.65      0.37      0.47        35
#
#     accuracy                           0.44        52
#    macro avg       0.48      0.48      0.44        52
# weighted avg       0.54      0.44      0.45        52
#
# Using PredefinedSplit: n_train=34, n_val=35
# hxgb ready for 501
#               precision    recall  f1-score   support
#
#            0       0.58      0.53      0.55        34
#            1       0.24      0.28      0.26        18
#
#     accuracy                           0.44        52
#    macro avg       0.41      0.40      0.41        52
# weighted avg       0.46      0.44      0.45        52
#
# Using PredefinedSplit: n_train=42, n_val=71
# hxgb ready for 502
#               precision    recall  f1-score   support
#
#            0       0.72      0.65      0.68        20
#            1       0.79      0.84      0.82        32
#
#     accuracy                           0.77        52
#    macro avg       0.76      0.75      0.75        52
# weighted avg       0.77      0.77      0.77        52
#
# Using PredefinedSplit: n_train=49, n_val=102
# hxgb ready for 503
#               precision    recall  f1-score   support
#
#            0       0.55      0.97      0.70        29
#            1       0.00      0.00      0.00        23
#
#     accuracy                           0.54        52
#    macro avg       0.27      0.48      0.35        52
# weighted avg       0.31      0.54      0.39        52
#
# Using PredefinedSplit: n_train=25, n_val=64
# hxgb ready for 504
#               precision    recall  f1-score   support
#
#            0       0.76      0.65      0.70        20
#            1       0.80      0.88      0.84        32
#
#     accuracy                           0.79        52
#    macro avg       0.78      0.76      0.77        52
# weighted avg       0.79      0.79      0.78        52
#
# Using PredefinedSplit: n_train=39, n_val=87
# hxgb ready for 505
#               precision    recall  f1-score   support
#
#            0       0.56      0.62      0.59        29
#            1       0.45      0.39      0.42        23
#
#     accuracy                           0.52        52
#    macro avg       0.51      0.51      0.50        52
# weighted avg       0.51      0.52      0.51        52
#
# Using PredefinedSplit: n_train=42, n_val=67
# hxgb ready for 506

# %%
for canton in cantons[60:70]: 
    instancia = Model(df, canton)
    X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = instancia.partition()
    instancia.hybrid("hxgb", X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.62      0.42      0.50        31
#            1       0.42      0.62      0.50        21
#
#     accuracy                           0.50        52
#    macro avg       0.52      0.52      0.50        52
# weighted avg       0.54      0.50      0.50        52
#
# Using PredefinedSplit: n_train=38, n_val=56
# hxgb ready for 507
#               precision    recall  f1-score   support
#
#            0       0.87      0.62      0.73        32
#            1       0.59      0.85      0.69        20
#
#     accuracy                           0.71        52
#    macro avg       0.73      0.74      0.71        52
# weighted avg       0.76      0.71      0.71        52
#
# Using PredefinedSplit: n_train=32, n_val=33
# hxgb ready for 508
#               precision    recall  f1-score   support
#
#            0       0.82      0.93      0.87        43
#            1       0.00      0.00      0.00         9
#
#     accuracy                           0.77        52
#    macro avg       0.41      0.47      0.43        52
# weighted avg       0.68      0.77      0.72        52
#
# Using PredefinedSplit: n_train=17, n_val=30
# hxgb ready for 509
#               precision    recall  f1-score   support
#
#            0       0.46      0.79      0.58        24
#            1       0.55      0.21      0.31        28
#
#     accuracy                           0.48        52
#    macro avg       0.50      0.50      0.45        52
# weighted avg       0.51      0.48      0.44        52
#
# Using PredefinedSplit: n_train=39, n_val=47
# hxgb ready for 510
#               precision    recall  f1-score   support
#
#            0       0.80      0.88      0.84        41
#            1       0.29      0.18      0.22        11
#
#     accuracy                           0.73        52
#    macro avg       0.54      0.53      0.53        52
# weighted avg       0.69      0.73      0.71        52
#
# Using PredefinedSplit: n_train=8, n_val=33
# hxgb ready for 511
# c:\Users\nan\OneDrive\Documentos\ucr\practica profesiona\dengue-model\.venv\Lib\site-packages\sklearn\model_selection\_search.py:1137: UserWarning: One or more of the test scores are non-finite: [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan]
#   warnings.warn(
#               precision    recall  f1-score   support
#
#            0       0.32      0.90      0.47        10
#            1       0.96      0.55      0.70        42
#
#     accuracy                           0.62        52
#    macro avg       0.64      0.72      0.59        52
# weighted avg       0.84      0.62      0.65        52
#
# Using PredefinedSplit: n_train=52, n_val=176
# hxgb ready for 601
#               precision    recall  f1-score   support
#
#            0       0.25      1.00      0.40         4
#            1       1.00      0.75      0.86        48
#
#     accuracy                           0.77        52
#    macro avg       0.62      0.88      0.63        52
# weighted avg       0.94      0.77      0.82        52
#
# Using PredefinedSplit: n_train=48, n_val=97
# hxgb ready for 602
#               precision    recall  f1-score   support
#
#            0       0.66      0.75      0.70        36
#            1       0.18      0.12      0.15        16
#
#     accuracy                           0.56        52
#    macro avg       0.42      0.44      0.42        52
# weighted avg       0.51      0.56      0.53        52
#
# Using PredefinedSplit: n_train=49, n_val=92
# hxgb ready for 603
#               precision    recall  f1-score   support
#
#            0       0.67      0.93      0.78        28
#            1       0.85      0.46      0.59        24
#
#     accuracy                           0.71        52
#    macro avg       0.76      0.69      0.69        52
# weighted avg       0.75      0.71      0.69        52
#
# Using PredefinedSplit: n_train=41, n_val=42
# hxgb ready for 604
#               precision    recall  f1-score   support
#
#            0       0.31      0.73      0.43        11
#            1       0.88      0.56      0.69        41
#
#     accuracy                           0.60        52
#    macro avg       0.60      0.64      0.56        52
# weighted avg       0.76      0.60      0.63        52
#
# Using PredefinedSplit: n_train=46, n_val=79
# hxgb ready for 605

# %%
for canton in cantons[70:82]: 
    instancia = Model(df, canton)
    X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = instancia.partition()
    instancia.hybrid("hxgb", X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.67      0.77        46
#            1       0.12      0.33      0.17         6
#
#     accuracy                           0.63        52
#    macro avg       0.50      0.50      0.47        52
# weighted avg       0.80      0.63      0.70        52
#
# Using PredefinedSplit: n_train=38, n_val=82
# hxgb ready for 606
#               precision    recall  f1-score   support
#
#            0       0.72      0.56      0.63        32
#            1       0.48      0.65      0.55        20
#
#     accuracy                           0.60        52
#    macro avg       0.60      0.61      0.59        52
# weighted avg       0.63      0.60      0.60        52
#
# Using PredefinedSplit: n_train=45, n_val=66
# hxgb ready for 607
#               precision    recall  f1-score   support
#
#            0       0.84      0.86      0.85        44
#            1       0.14      0.12      0.13         8
#
#     accuracy                           0.75        52
#    macro avg       0.49      0.49      0.49        52
# weighted avg       0.74      0.75      0.74        52
#
# Using PredefinedSplit: n_train=17, n_val=20
# hxgb ready for 608
#               precision    recall  f1-score   support
#
#            0       0.67      0.48      0.56        21
#            1       0.70      0.84      0.76        31
#
#     accuracy                           0.69        52
#    macro avg       0.68      0.66      0.66        52
# weighted avg       0.69      0.69      0.68        52
#
# Using PredefinedSplit: n_train=33, n_val=84
# hxgb ready for 609
#               precision    recall  f1-score   support
#
#            0       0.48      0.92      0.63        24
#            1       0.67      0.14      0.24        28
#
#     accuracy                           0.50        52
#    macro avg       0.57      0.53      0.43        52
# weighted avg       0.58      0.50      0.42        52
#
# Using PredefinedSplit: n_train=50, n_val=125
# hxgb ready for 610
#               precision    recall  f1-score   support
#
#            0       0.77      0.71      0.74        34
#            1       0.52      0.61      0.56        18
#
#     accuracy                           0.67        52
#    macro avg       0.65      0.66      0.65        52
# weighted avg       0.69      0.67      0.68        52
#
# Using PredefinedSplit: n_train=43, n_val=65
# hxgb ready for 611
#               precision    recall  f1-score   support
#
#            0       0.22      0.62      0.33        13
#            1       0.69      0.28      0.40        39
#
#     accuracy                           0.37        52
#    macro avg       0.45      0.45      0.36        52
# weighted avg       0.57      0.37      0.38        52
#
# Using PredefinedSplit: n_train=42, n_val=161
# hxgb ready for 701
#               precision    recall  f1-score   support
#
#            0       0.40      0.25      0.31        16
#            1       0.71      0.83      0.77        36
#
#     accuracy                           0.65        52
#    macro avg       0.56      0.54      0.54        52
# weighted avg       0.62      0.65      0.63        52
#
# Using PredefinedSplit: n_train=49, n_val=193
# hxgb ready for 702
#               precision    recall  f1-score   support
#
#            0       0.69      0.78      0.74        32
#            1       0.56      0.45      0.50        20
#
#     accuracy                           0.65        52
#    macro avg       0.63      0.62      0.62        52
# weighted avg       0.64      0.65      0.64        52
#
# Using PredefinedSplit: n_train=48, n_val=181
# hxgb ready for 703
#               precision    recall  f1-score   support
#
#            0       0.57      0.42      0.48        31
#            1       0.38      0.52      0.44        21
#
#     accuracy                           0.46        52
#    macro avg       0.47      0.47      0.46        52
# weighted avg       0.49      0.46      0.46        52
#
# Using PredefinedSplit: n_train=39, n_val=194
# hxgb ready for 704
#               precision    recall  f1-score   support
#
#            0       0.60      0.68      0.64        31
#            1       0.41      0.33      0.37        21
#
#     accuracy                           0.54        52
#    macro avg       0.51      0.51      0.50        52
# weighted avg       0.52      0.54      0.53        52
#
# Using PredefinedSplit: n_train=45, n_val=147
# hxgb ready for 705
#               precision    recall  f1-score   support
#
#            0       0.64      0.72      0.68        32
#            1       0.44      0.35      0.39        20
#
#     accuracy                           0.58        52
#    macro avg       0.54      0.53      0.53        52
# weighted avg       0.56      0.58      0.57        52
#
# Using PredefinedSplit: n_train=48, n_val=193
# hxgb ready for 706

# %% [markdown]
# ## Save metrics

# %%
cod_cant_hxgb = []
nrmse_hxgb = []

for canton in cantons: 
    instancia = Model(df, canton)
    cant_temp, nrmse_temp = instancia.calculate_nrmse("hxgb")
    cod_cant_hxgb.append(canton)
    nrmse_hxgb.append(nrmse_temp)

nrmse_hxgb = pd.DataFrame({"canton": cod_cant_hxgb,
                         "nrmse": nrmse_hxgb})

nrmse_hxgb.to_csv("../../data/model_results/metrics/hxgb.csv")
# Out:
# c:\Users\nan\OneDrive\Documentos\ucr\practica profesiona\dengue-model\models\model_scripts\../../models\model_rr.py:548: RuntimeWarning: invalid value encountered in scalar divide
#   nrmse = rmse / np.mean(results["actual"])

# %% [markdown]
# ## Best

# %%
nrmse_hxgb = pd.read_csv("../../data/model_results/metrics/hxgb.csv")

nrmse_hxgb = nrmse_hxgb[np.isfinite(nrmse_hxgb)] # Prevent using cantons with an NRMSE undefined because their mean cases is 0
nrmse_hxgb = nrmse_hxgb[nrmse_hxgb["nrmse"].notnull()] # Prevent using cantons with an NRMSE undefined because their mean cases is 0

# %%
best_hxgb = Model(df, cantons[nrmse_hxgb["nrmse"].idxmin()])

# %% [markdown]
# ### Plot results

# %%
X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = best_hxgb.partition()
y_pred_point, lower_bound, upper_bound = best_hxgb.prediction_intervals(X_combined, y_combined, X_test, epsilon, "hxgb", repeats = 100)
best_hxgb.serie_temp_canton("hxgb", y_pred_point, lower_bound, upper_bound)

# %% [markdown]
# ### Confidence intervals for NRMSE

# %%
print(f"Best canton NRMSE for HXGB: {round(nrmse_hxgb.iloc[nrmse_hxgb["nrmse"].idxmin(), 2], 4)}")
# Out:
# Best canton NRMSE for HXGB: 0.3533

# %%
X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = best_hxgb.partition()
best_hxgb.confint_nrmse("hxgb", X_combined, y_combined, X_test, y_test, epsilon, n_bootstraps = 100)
# Out:
# Only one class present in test set for classification. Skipping classification step.
# point estimate: 0.49
# lower bound: 0.34, upper bound: 0.93

# %% [markdown]
# ### Feature importance

# %%
X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = best_hxgb.partition()
best_hxgb.var_importance(X_test, y_test, "hxgb", repeats = 100, var = "RR")
# Out:
#                 Feature  imp_hxgb  std_hxgb
# 0              rr_lag_2  0.027977  0.028808
# 1              rr_lag_1  0.026117  0.016658
# 2            ndvi_lag_1  0.007191  0.003602
# 3            ndvi_lag_4  0.002724  0.001454
# 4       tmin_mean_lag_4  0.001909  0.004169
# ..                  ...       ...       ...
# 101  precip_total_lag_4 -0.001708  0.002532
# 102    precip_max_lag_1 -0.001839  0.002311
# 103     tmax_mean_lag_3 -0.003546  0.003046
# 104          ndvi_lag_2 -0.006145  0.003285
# 105            rr_lag_4 -0.009483  0.005712
#
# [106 rows x 3 columns]
#                 Feature  imp_hxgb  std_hxgb
# 0              rr_lag_2  0.027977  0.028808
# 1              rr_lag_1  0.026117  0.016658
# 2            ndvi_lag_1  0.007191  0.003602
# 3            ndvi_lag_4  0.002724  0.001454
# 4       tmin_mean_lag_4  0.001909  0.004169
# ..                  ...       ...       ...
# 101  precip_total_lag_4 -0.001708  0.002532
# 102    precip_max_lag_1 -0.001839  0.002311
# 103     tmax_mean_lag_3 -0.003546  0.003046
# 104          ndvi_lag_2 -0.006145  0.003285
# 105            rr_lag_4 -0.009483  0.005712
#
# [106 rows x 3 columns]

# %% [markdown]
# ### Feature selection

# %%
X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = best_hxgb.partition()
best_hxgb.rfecv_selection("hxgb", X_combined, y_combined, X_test, y_test, pds, repeats = 100, var = "RR")
# Out:
# Optimal number of features for RR and hxgb: 15
# Selected features: ['rr_lag_3', 'rr_lag_2', 'rr_lag_1', 'tmin_mean_lag_4', 'tmin_mean_lag_3', 'tmin_mean_lag_2', 'tmin_mean_lag_1', 'nino34ssta_lag_1', 'temp_prom_lag_4', 'fiebre_lag_3', 'fiebre_lag_1', 'empleo_lag_4', 'empleo_lag_3', 'vacaciones_lag_4', 'precip_total_lag_1']
# New NRMSE with selected features: 0.3222

# %% [markdown]
# ## Worst

# %%
nrmse_hxgb = pd.read_csv("../../data/model_results/metrics/hxgb.csv")

nrmse_hxgb = nrmse_hxgb[np.isfinite(nrmse_hxgb)] # Prevent using cantons with an NRMSE undefined because their mean cases is 0
nrmse_hxgb = nrmse_hxgb[nrmse_hxgb["nrmse"].notnull()] # Prevent using cantons with an NRMSE undefined because their mean cases is 0

# %%
worst_hxgb = Model(df, cantons[nrmse_hxgb["nrmse"].idxmax()])

# %% [markdown]
# ### Plot results

# %%
X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = worst_hxgb.partition()
y_pred_point, lower_bound, upper_bound = worst_hxgb.prediction_intervals(X_combined, y_combined, X_test, epsilon, "hxgb", repeats = 100)
worst_hxgb.serie_temp_canton("hxgb", y_pred_point, lower_bound, upper_bound)

# %% [markdown]
# ### Confidence intervals for NRMSE

# %%
print(f"Worst canton NRMSE for HXGB: {round(nrmse_hxgb.iloc[nrmse_hxgb["nrmse"].idxmax(), 2], 4)}")
# Out:
# Worst canton NRMSE for HXGB: 22.5615

# %%
X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = worst_hxgb.partition()
worst_hxgb.confint_nrmse("hxgb", X_combined, y_combined, X_test, y_test, epsilon, n_bootstraps = 100)
# Out:
# point estimate: 7.21
# lower bound: 7.21, upper bound: 7.21

# %% [markdown]
# ### Feature importance

# %%
X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = worst_hxgb.partition()
worst_hxgb.var_importance(X_test, y_test, "hxgb", repeats = 100, var = "RR")
# Out:
#                 Feature  imp_hxgb  std_hxgb
# 0            ndvi_lag_4  0.347100  0.218853
# 1       tmax_mean_lag_4  0.040227  0.010754
# 2       tmax_mean_lag_2  0.037859  0.052102
# 3    precip_total_lag_4  0.009955  0.240452
# 4              rr_lag_4  0.008694  0.010893
# ..                  ...       ...       ...
# 101    precip_min_lag_1 -0.004315  0.002666
# 102            rr_lag_2 -0.005091  0.006001
# 103        empleo_lag_3 -0.016978  0.008638
# 104            rr_lag_1 -0.118729  0.131636
# 105          nino34ssta -0.258398  0.130514
#
# [106 rows x 3 columns]
#                 Feature  imp_hxgb  std_hxgb
# 0            ndvi_lag_4  0.347100  0.218853
# 1       tmax_mean_lag_4  0.040227  0.010754
# 2       tmax_mean_lag_2  0.037859  0.052102
# 3    precip_total_lag_4  0.009955  0.240452
# 4              rr_lag_4  0.008694  0.010893
# ..                  ...       ...       ...
# 101    precip_min_lag_1 -0.004315  0.002666
# 102            rr_lag_2 -0.005091  0.006001
# 103        empleo_lag_3 -0.016978  0.008638
# 104            rr_lag_1 -0.118729  0.131636
# 105          nino34ssta -0.258398  0.130514
#
# [106 rows x 3 columns]

# %% [markdown]
# ### Feature selection

# %%
X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = worst_hxgb.partition()
worst_hxgb.rfecv_selection("hxgb", X_combined, y_combined, X_test, y_test, pds, repeats = 100, var = "RR")
# Out:
# Optimal number of features for RR and hxgb: 5
# Selected features: ['rr_lag_1', 'empleo_lag_4', 'suspension_de_agua_lag_2', 'dengue_lag_1', 'precip_total_lag_4']
# New NRMSE with selected features: -0.4774
