# %% [markdown]
# # Model results for each canton
#
# 1. reg reg
# 2. reg rf
# 3. reg

# %% [markdown]
# ## Initial configuration

# %%
import pandas as pd
import sys
import numpy as np

sys.path.append('../../models')

from model_rr import Model

# %%
df = pd.read_csv('../../data/clean/full_data.csv')

# %%
cantons = [101, 102, 103, 104, 105, 106, 107, 108, 109, 110, 111, 112, 113, 114, 115, 116, 117, 118, 119, 120, 201, -202, 203, 204, 205, 206, 207, 208, 209, 210, 211, 212, 213, 214, 215, 216, 301, 302, 303, 304, 305, 306, 307, 308, 401, 402, 403, 404, 405, 406, 407, 408, 409, 410, 501, 502, 503, 504, 505, 506, 507, 508, 509, 510, 511, 601, 602, 603, 604, 605, 606, 607, 608, 609, 610, 611, 701, 702, 703, 704, 705, 706]

cantons = [str(x) for x in cantons]

# %% [markdown]
# # Random Forest

# %% [markdown]
# ## Fitting the models

# %%
for canton in cantons[0:10]: 
    instancia = Model(df, canton)
    X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = instancia.partition()
    instancia.rf_reg(X_combined, y_combined, X_test, y_test, test, pds, epsilon)
# Out:
# RF Model Ready for 101
# RF Model Ready for 102
# RF Model Ready for 103
# RF Model Ready for 104
# RF Model Ready for 105
# RF Model Ready for 106
# RF Model Ready for 107
# RF Model Ready for 108
# RF Model Ready for 109
# RF Model Ready for 110

# %%
for canton in cantons[10:20]: 
    instancia = Model(df, canton)
    X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = instancia.partition()
    instancia.rf_reg(X_combined, y_combined, X_test, y_test, test, pds, epsilon)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 4
#       1 for canton in cantons[10:20]:
#       2     instancia = Model(df, canton)
#       3     X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = instancia.partition()
# ----> 4     instancia.rf_reg(X_combined, y_combined, X_test, y_test, test, pds, epsilon)
#
# File c:\Users\nan\OneDrive\Documentos\ucr\practica profesiona\dengue-model\models\model_scripts\../../models\model_rr.py:522, in Model.rf_reg(self, X_combined, y_combined, X_test, y_test, test, pds, epsilon)
#     508 param_grid_rf = {
#     509     'max_depth': [3, 5, 7, 9],
#     510     'min_samples_split': [10, 50, 75, 100, 150],
#     511     'ccp_alpha': [0, 1 /  10**5, 1 / 10**4, 1 / 10**3, 0.01, 0.1, 1, 10],
#     512     "criterion": ["squared_error", "absolute_error"]
#     513 }
#     515 grid_rf = GridSearchCV(
# ...

# %%
instancia = Model(df, "201")
X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = instancia.partition()
instancia.rf_reg(X_combined, y_combined, X_test, y_test, test, pds, epsilon)
# Out:
# RF Model Ready for 201

# %%
for canton in cantons[22:30]: 
    instancia = Model(df, canton)
    X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = instancia.partition()
    instancia.rf_reg(X_combined, y_combined, X_test, y_test, test, pds, epsilon)
# Out:
# RF Model Ready for 203
# RF Model Ready for 204
# RF Model Ready for 205
# RF Model Ready for 206
# RF Model Ready for 207
# RF Model Ready for 208
# RF Model Ready for 209
# RF Model Ready for 210

# %%
instancia = Model(df, "-202")
X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = instancia.partition()
instancia.rf_reg(X_combined, y_combined, X_test, y_test, test, pds, epsilon)
# Out:
# RF Model Ready for -202

# %%
for canton in cantons[30:40]: 
    instancia = Model(df, canton)
    X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = instancia.partition()
    instancia.rf_reg(X_combined, y_combined, X_test, y_test, test, pds, epsilon)
# Out:
# RF Model Ready for 211
# RF Model Ready for 212
# RF Model Ready for 213
# RF Model Ready for 214
# RF Model Ready for 215
# RF Model Ready for 216
# RF Model Ready for 301
# RF Model Ready for 302
# RF Model Ready for 303
# RF Model Ready for 304

# %%
for canton in cantons[40:50]: 
    instancia = Model(df, canton)
    X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = instancia.partition()
    instancia.rf_reg(X_combined, y_combined, X_test, y_test, test, pds, epsilon)
# Out:
# RF Model Ready for 305
# RF Model Ready for 306
# RF Model Ready for 307
# RF Model Ready for 308
# RF Model Ready for 401
# RF Model Ready for 402
# RF Model Ready for 403
# RF Model Ready for 404
# RF Model Ready for 405
# RF Model Ready for 406

# %%
for canton in cantons[50:60]: 
    instancia = Model(df, canton)
    X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = instancia.partition()
    instancia.rf_reg(X_combined, y_combined, X_test, y_test, test, pds, epsilon)
# Out:
# RF Model Ready for 407
# RF Model Ready for 408
# RF Model Ready for 409
# RF Model Ready for 410
# RF Model Ready for 501
# RF Model Ready for 502
# RF Model Ready for 503
# RF Model Ready for 504
# RF Model Ready for 505
# RF Model Ready for 506

# %%
for canton in cantons[60:70]: 
    instancia = Model(df, canton)
    X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = instancia.partition()
    instancia.rf_reg(X_combined, y_combined, X_test, y_test, test, pds, epsilon)
# Out:
# RF Model Ready for 507
# RF Model Ready for 508
# RF Model Ready for 509
# RF Model Ready for 510
# RF Model Ready for 511
# RF Model Ready for 601
# RF Model Ready for 602
# RF Model Ready for 603
# RF Model Ready for 604
# RF Model Ready for 605

# %%
for canton in cantons[70:82]: 
    instancia = Model(df, canton)
    X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = instancia.partition()
    instancia.rf_reg(X_combined, y_combined, X_test, y_test, test, pds, epsilon)
# Out:
# RF Model Ready for 606
# RF Model Ready for 607
# RF Model Ready for 608
# RF Model Ready for 609
# RF Model Ready for 610
# RF Model Ready for 611
# RF Model Ready for 701
# RF Model Ready for 702
# RF Model Ready for 703
# RF Model Ready for 704
# RF Model Ready for 705
# RF Model Ready for 706

# %%
instancia = Model(df, "601") # Retrain after adding cantons that were not considered, Monteverde an PJ
X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = instancia.partition()
instancia.rf_reg(X_combined, y_combined, X_test, y_test, test, pds, epsilon)
# Out:
# RF Model Ready for 601

# %%
instancia = Model(df, "607") # Retrain after adding cantons that were not considered, Monteverde an PJ
X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = instancia.partition()
instancia.rf_reg(X_combined, y_combined, X_test, y_test, test, pds, epsilon)
# Out:
# RF Model Ready for 607

# %% [markdown]
# ## Save metrics

# %%
cod_cant_rf = []
nrmse_rf = []

for canton in cantons: 
    instancia = Model(df, canton)
    X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = instancia.partition()
    cant_temp, nrmse_temp = instancia.calculate_nrmse("rf", epsilon)
    cod_cant_rf.append(canton)
    nrmse_rf.append(nrmse_temp)

nrmse_rf = pd.DataFrame({"canton": cod_cant_rf,
                         "nrmse": nrmse_rf})

# %%
nrmse_rf.to_csv("../../data/model_results/metrics/rf.csv")

# %% [markdown]
# ## Best

# %%
nrmse_rf = pd.read_csv("../../data/model_results/metrics/rf.csv")

nrmse_rf = nrmse_rf[np.isfinite(nrmse_rf)] # Prevent using cantons with an NRMSE undefined because their mean cases is 0
nrmse_rf = nrmse_rf[nrmse_rf["nrmse"].notnull()] # Prevent using cantons with an NRMSE undefined because their mean cases is 0

# %%
nrmse_rf = pd.read_csv("../../data/model_results/metrics/rf.csv")

best_rf = Model(df, cantons[nrmse_rf["nrmse"].idxmin()])

# %% [markdown]
# ### Plot results

# %%
X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = best_rf.partition()
y_pred_point, lower_bound, upper_bound = best_rf.prediction_intervals(X_combined, y_combined, X_test, epsilon, "rf", repeats = 100)
best_rf.serie_temp_canton("rf", y_pred_point, lower_bound, upper_bound)

# %% [markdown]
# ### Confidence interval for NRMSE

# %%
print(f"Best canton NRMSE: {round(nrmse_rf.iloc[nrmse_rf["nrmse"].idxmin(), 2], 4)}")
# Out:
# Best canton NRMSE: 0.1263

# %%
X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = best_rf.partition()
best_rf.confint_nrmse("rf", X_combined, y_combined, X_test, y_test, epsilon, n_bootstraps = 100)
# Out:
# point estimate: 0.45
# lower bound: 0.0, upper bound: 2.8

# %% [markdown]
# ### Feature importance

# %%
X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = best_rf.partition()
best_rf.var_importance(X_combined, y_combined, X_test, y_test, "rf", epsilon, repeats = 100, var = "RR")
# Out:
#                  Feature    imp_rf    std_rf
# 0    precip_median_lag_4  0.001061  0.001236
# 1           fiebre_lag_4  0.000957  0.001384
# 2       vacaciones_lag_3  0.000533  0.000714
# 3               rr_lag_2  0.000000  0.000000
# 4               rr_lag_3  0.000000  0.000000
# ..                   ...       ...       ...
# 101     precip_min_lag_4  0.000000  0.000000
# 102     precip_min_lag_1  0.000000  0.000000
# 103     precip_min_lag_2  0.000000  0.000000
# 104                urb_0  0.000000  0.000000
# 105         empleo_lag_2 -0.000237  0.000215
#
# [106 rows x 3 columns]
#                  Feature    imp_rf    std_rf
# 0    precip_median_lag_4  0.001061  0.001236
# 1           fiebre_lag_4  0.000957  0.001384
# 2       vacaciones_lag_3  0.000533  0.000714
# 3               rr_lag_2  0.000000  0.000000
# 4               rr_lag_3  0.000000  0.000000
# ..                   ...       ...       ...
# 101     precip_min_lag_4  0.000000  0.000000
# ...

# %% [markdown]
# ### Feature selection

# %%
X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = best_rf.partition()
best_rf.rfecv_selection("rf", X_combined, y_combined, X_test, y_test, pds, epsilon, repeats = 100, var = "RR")
# Out:
# Optimal number of features for RR and rf: 5
# Selected features: ['tmin_mean_lag_3', 'tmin_mean_lag_1', 'aedes_aegypti_lag_1', 'comprar_carro_lag_3', 'corte_de_agua_lag_3']
# New NRMSE with selected features: 0.0000

# %% [markdown]
# ## Worst

# %%
nrmse_rf = pd.read_csv("../../data/model_results/metrics/rf.csv")

nrmse_rf = nrmse_rf[np.isfinite(nrmse_rf)] # Prevent using cantons with an NRMSE undefined because their mean cases is 0
nrmse_rf = nrmse_rf[nrmse_rf["nrmse"].notnull()] # Prevent using cantons with an NRMSE undefined because their mean cases is 0

# %%
worst_rf = Model(df, cantons[nrmse_rf["nrmse"].idxmax()])

# %% [markdown]
# ### Plot results

# %%
X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = worst_rf.partition()
y_pred_point, lower_bound, upper_bound = worst_rf.prediction_intervals(X_combined, y_combined, X_test, epsilon, "rf", repeats = 100)
worst_rf.serie_temp_canton("rf", y_pred_point, lower_bound, upper_bound)

# %% [markdown]
# ### Confidence interval for NRMSE

# %%
print(f"Worst canton NRMSE for RF: {round(nrmse_rf.iloc[nrmse_rf["nrmse"].idxmax(), 2], 4)}")
# Out:
# Worst canton NRMSE for RF: 3.6835

# %%
X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = worst_rf.partition()
worst_rf.confint_nrmse("rf", X_combined, y_combined, X_test, y_test, epsilon, n_bootstraps = 100)
# Out:
# point estimate: 3.96
# lower bound: 3.62, upper bound: 5.31

# %% [markdown]
# ### Feature importance

# %%
X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = worst_rf.partition()
worst_rf.var_importance(X_combined, y_combined, X_test, y_test, "rf", epsilon, repeats = 100, var = "RR")
# Out:
#                  Feature    imp_rf    std_rf
# 0    precip_median_lag_3  0.005996  0.008159
# 1       precip_max_lag_4  0.005059  0.002039
# 2        temp_prom_lag_3  0.003802  0.001524
# 3               rr_lag_2  0.003765  0.012648
# 4               rr_lag_4  0.003560  0.010153
# ..                   ...       ...       ...
# 101         empleo_lag_3 -0.002803  0.011039
# 102             rr_lag_1 -0.003897  0.055933
# 103         fiebre_lag_4 -0.004957  0.015268
# 104           ndvi_lag_3 -0.023979  0.019591
# 105           ndvi_lag_4 -0.024527  0.016506
#
# [106 rows x 3 columns]
#                  Feature    imp_rf    std_rf
# 0    precip_median_lag_3  0.005996  0.008159
# 1       precip_max_lag_4  0.005059  0.002039
# 2        temp_prom_lag_3  0.003802  0.001524
# 3               rr_lag_2  0.003765  0.012648
# 4               rr_lag_4  0.003560  0.010153
# ..                   ...       ...       ...
# 101         empleo_lag_3 -0.002803  0.011039
# ...

# %% [markdown]
# ### Feature selection

# %%
X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = worst_rf.partition()
worst_rf.rfecv_selection("rf", X_combined, y_combined, X_test, y_test, pds, epsilon, repeats = 100, var = "RR")
# Out:
# Optimal number of features for RR and rf: 7
# Selected features: ['rr_lag_4', 'rr_lag_3', 'rr_lag_2', 'rr_lag_1', 'ndvi_lag_4', 'nino34ssta_lag_1', 'dengue_lag_1']
# New NRMSE with selected features: 3.7651

# %% [markdown]
# # XGB

# %% [markdown]
# ## Fit models

# %%
for canton in cantons[0:10]: 
    instancia = Model(df, canton)
    X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = instancia.partition()
    instancia.xgb_reg(X_combined, y_combined, X_test, y_test, test, pds, epsilon)
# Out:
# XGB Model Ready for 101
# XGB Model Ready for 102
# XGB Model Ready for 103
# XGB Model Ready for 104
# XGB Model Ready for 105
# XGB Model Ready for 106
# XGB Model Ready for 107
# XGB Model Ready for 108
# XGB Model Ready for 109
# XGB Model Ready for 110

# %%
for canton in cantons[10:20]: 
    instancia = Model(df, canton)
    X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = instancia.partition()
    instancia.xgb_reg(X_combined, y_combined, X_test, y_test, test, pds, epsilon)
# Out:
# XGB Model Ready for 111
# XGB Model Ready for 112
# XGB Model Ready for 113
# XGB Model Ready for 114
# XGB Model Ready for 115
# XGB Model Ready for 116
# XGB Model Ready for 117
# XGB Model Ready for 118
# XGB Model Ready for 119
# XGB Model Ready for 120

# %%
instancia = Model(df, "201")
X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = instancia.partition()
instancia.xgb_reg(X_combined, y_combined, X_test, y_test, test, pds, epsilon)
# Out:
# XGB Model Ready for 201

# %%
for canton in cantons[22:30]: 
    instancia = Model(df, canton)
    X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = instancia.partition()
    instancia.xgb_reg(X_combined, y_combined, X_test, y_test, test, pds, epsilon)
# Out:
# XGB Model Ready for 203
# XGB Model Ready for 204
# XGB Model Ready for 205
# XGB Model Ready for 206
# XGB Model Ready for 207
# XGB Model Ready for 208
# XGB Model Ready for 209
# XGB Model Ready for 210

# %%
instancia = Model(df, "-202")
X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = instancia.partition()
instancia.xgb_reg(X_combined, y_combined, X_test, y_test, test, pds, epsilon)
# Out:
# XGB Model Ready for -202

# %%
for canton in cantons[30:40]: 
    instancia = Model(df, canton)
    X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = instancia.partition()
    instancia.xgb_reg(X_combined, y_combined, X_test, y_test, test, pds, epsilon)
# Out:
# XGB Model Ready for 211
# XGB Model Ready for 212
# XGB Model Ready for 213
# XGB Model Ready for 214
# XGB Model Ready for 215
# XGB Model Ready for 216
# XGB Model Ready for 301
# XGB Model Ready for 302
# XGB Model Ready for 303
# XGB Model Ready for 304

# %%
for canton in cantons[40:50]: 
    instancia = Model(df, canton)
    X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = instancia.partition()
    instancia.xgb_reg(X_combined, y_combined, X_test, y_test, test, pds, epsilon)
# Out:
# XGB Model Ready for 305
# XGB Model Ready for 306
# XGB Model Ready for 307
# XGB Model Ready for 308
# XGB Model Ready for 401
# XGB Model Ready for 402
# XGB Model Ready for 403
# XGB Model Ready for 404
# XGB Model Ready for 405
# XGB Model Ready for 406

# %%
for canton in cantons[50:60]: 
    instancia = Model(df, canton)
    X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = instancia.partition()
    instancia.xgb_reg(X_combined, y_combined, X_test, y_test, test, pds, epsilon)
# Out:
# XGB Model Ready for 407
# XGB Model Ready for 408
# XGB Model Ready for 409
# XGB Model Ready for 410
# XGB Model Ready for 501
# XGB Model Ready for 502
# XGB Model Ready for 503
# XGB Model Ready for 504
# XGB Model Ready for 505
# XGB Model Ready for 506

# %%
for canton in cantons[60:70]: 
    instancia = Model(df, canton)
    X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = instancia.partition()
    instancia.xgb_reg(X_combined, y_combined, X_test, y_test, test, pds, epsilon)
# Out:
# XGB Model Ready for 507
# XGB Model Ready for 508
# XGB Model Ready for 509
# XGB Model Ready for 510
# XGB Model Ready for 511
# XGB Model Ready for 601
# XGB Model Ready for 602
# XGB Model Ready for 603
# XGB Model Ready for 604
# XGB Model Ready for 605

# %%
for canton in cantons[70:82]: 
    instancia = Model(df, canton)
    X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = instancia.partition()
    instancia.xgb_reg(X_combined, y_combined, X_test, y_test, test, pds, epsilon)
# Out:
# XGB Model Ready for 606
# XGB Model Ready for 607
# XGB Model Ready for 608
# XGB Model Ready for 609
# XGB Model Ready for 610
# XGB Model Ready for 611
# XGB Model Ready for 701
# XGB Model Ready for 702
# XGB Model Ready for 703
# XGB Model Ready for 704
# XGB Model Ready for 705
# XGB Model Ready for 706

# %%
instancia = Model(df, "601") # Retrain with cantons that were not considered
X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = instancia.partition()
instancia.xgb_reg(X_combined, y_combined, X_test, y_test, test, pds, epsilon)
# Out:
# XGB Model Ready for 601

# %%
instancia = Model(df, "607") # Retrain with cantons that were not considered
X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = instancia.partition()
instancia.xgb_reg(X_combined, y_combined, X_test, y_test, test, pds, epsilon)
# Out:
# XGB Model Ready for 607

# %% [markdown]
# ## Save metrics

# %%
cod_cant_xgb = []
nrmse_xgb = []

for canton in cantons: 
    instancia = Model(df, canton)
    X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = instancia.partition()
    cant_temp, nrmse_temp = instancia.calculate_nrmse("xgb", epsilon)
    cod_cant_xgb.append(canton)
    nrmse_xgb.append(nrmse_temp)

nrmse_xgb = pd.DataFrame({"canton": cod_cant_xgb,
                         "nrmse": nrmse_xgb})

nrmse_xgb.to_csv("../../data/model_results/metrics/xgb.csv")

# %% [markdown]
# ## Best

# %%
nrmse_xgb = pd.read_csv("../../data/model_results/metrics/xgb.csv")

nrmse_xgb = nrmse_xgb[np.isfinite(nrmse_xgb)] # Prevent using cantons with an NRMSE undefined because their mean cases is 0
nrmse_xgb = nrmse_xgb[nrmse_xgb["nrmse"].notnull()] # Prevent using cantons with an NRMSE undefined because their mean cases is 0

# %%
best_xgb = Model(df, cantons[nrmse_xgb["nrmse"].idxmin()])

# %% [markdown]
# ### Plot results

# %%
X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = best_xgb.partition()
y_pred_point, lower_bound, upper_bound = best_xgb.prediction_intervals(X_combined, y_combined, X_test, epsilon, "xgb", repeats = 100)
best_xgb.serie_temp_canton("xgb", y_pred_point, lower_bound, upper_bound)

# %% [markdown]
# ### Confidence interval for NRMSE

# %%
print(f"Best canton NRMSE for XGB: {round(nrmse_xgb.iloc[nrmse_xgb["nrmse"].idxmin(), 2], 4)}")
# Out:
# Best canton NRMSE for XGB: 0.0293

# %%
X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = best_xgb.partition()
best_xgb.confint_nrmse("xgb", X_combined, y_combined, X_test, y_test, epsilon, n_bootstraps = 100)
# Out:
# point estimate: 0.08
# lower bound: 0.0, upper bound: 0.3

# %% [markdown]
# ### Feature importance

# %%
X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = best_xgb.partition()
best_xgb.var_importance(X_combined, y_combined, X_test, y_test, "xgb", epsilon, repeats = 100, var = "RR")
# Out:
#               Feature  imp_xgb  std_xgb
# 0          nino34ssta      0.0      0.0
# 1            rr_lag_4      0.0      0.0
# 2            rr_lag_3      0.0      0.0
# 3            rr_lag_2      0.0      0.0
# 4            rr_lag_1      0.0      0.0
# ..                ...      ...      ...
# 101  precip_min_lag_4      0.0      0.0
# 102  precip_min_lag_3      0.0      0.0
# 103  precip_min_lag_2      0.0      0.0
# 104  precip_min_lag_1      0.0      0.0
# 105             urb_0      0.0      0.0
#
# [106 rows x 3 columns]
#               Feature  imp_xgb  std_xgb
# 0          nino34ssta      0.0      0.0
# 1            rr_lag_4      0.0      0.0
# 2            rr_lag_3      0.0      0.0
# 3            rr_lag_2      0.0      0.0
# 4            rr_lag_1      0.0      0.0
# ..                ...      ...      ...
# 101  precip_min_lag_4      0.0      0.0
# 102  precip_min_lag_3      0.0      0.0
# 103  precip_min_lag_2      0.0      0.0
# 104  precip_min_lag_1      0.0      0.0
# ...

# %% [markdown]
# ### Feature selection

# %%
X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = best_xgb.partition()
best_xgb.rfecv_selection("xgb", X_combined, y_combined, X_test, y_test, pds, epsilon, repeats = 100, var = "RR")
# Out:
# Optimal number of features for RR and xgb: 11
# Selected features: ['nino34ssta', 'ndvi_lag_4', 'tmin_mean_lag_3', 'aedes_aegypti_lag_1', 'criaderos_de_mosquito_lag_4', 'comprar_carro_lag_3', 'precip_total_lag_1', 'precip_min_lag_3', 'precip_min_lag_2', 'precip_min_lag_1', 'urb_0']
# New NRMSE with selected features: 0.0293

# %% [markdown]
# ## Worst

# %%
nrmse_xgb = pd.read_csv("../../data/model_results/metrics/xgb.csv")

nrmse_xgb = nrmse_xgb[np.isfinite(nrmse_xgb)] # Prevent using cantons with an NRMSE undefined because their mean cases is 0
nrmse_xgb = nrmse_xgb[nrmse_xgb["nrmse"].notnull()] # Prevent using cantons with an NRMSE undefined because their mean cases is 0

# %%
worst_xgb = Model(df, cantons[nrmse_xgb["nrmse"].idxmax()])

# %% [markdown]
# ### Plot results

# %%
X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = worst_xgb.partition()
y_pred_point, lower_bound, upper_bound = worst_xgb.prediction_intervals(X_combined, y_combined, X_test, epsilon, "xgb", repeats = 100)
worst_xgb.serie_temp_canton("xgb", y_pred_point, lower_bound, upper_bound)

# %% [markdown]
# ### Confidence interval for NRMSE

# %%
print(f"Worst canton NRMSE for XGB: {round(nrmse_xgb.iloc[nrmse_xgb["nrmse"].idxmax(), 2], 4)}")
# Out:
# Worst canton NRMSE for XGB: 3.5904

# %%
X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = worst_xgb.partition()
worst_xgb.confint_nrmse("xgb", X_combined, y_combined, X_test, y_test, epsilon, n_bootstraps = 100)
# Out:
# point estimate: 3.59
# lower bound: 3.58, upper bound: 3.61

# %% [markdown]
# ### Feature importance

# %%
X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = worst_xgb.partition()
worst_xgb.var_importance(X_combined, y_combined, X_test, y_test, "xgb", epsilon, repeats = 100, var = "RR")
# Out:
#                 Feature   imp_xgb   std_xgb
# 0            nino34ssta  0.001073  0.000771
# 1              rr_lag_4  0.000000  0.000000
# 2              rr_lag_2  0.000000  0.000000
# 3            ndvi_lag_1  0.000000  0.000000
# 4            ndvi_lag_2  0.000000  0.000000
# ..                  ...       ...       ...
# 101    nino34ssta_lag_4 -0.000141  0.001313
# 102          ndvi_lag_4 -0.000351  0.001091
# 103            rr_lag_3 -0.001334  0.003645
# 104  precip_total_lag_4 -0.001413  0.002158
# 105            rr_lag_1 -0.002810  0.006085
#
# [106 rows x 3 columns]
#                 Feature   imp_xgb   std_xgb
# 0            nino34ssta  0.001073  0.000771
# 1              rr_lag_4  0.000000  0.000000
# 2              rr_lag_2  0.000000  0.000000
# 3            ndvi_lag_1  0.000000  0.000000
# 4            ndvi_lag_2  0.000000  0.000000
# ..                  ...       ...       ...
# 101    nino34ssta_lag_4 -0.000141  0.001313
# 102          ndvi_lag_4 -0.000351  0.001091
# ...

# %% [markdown]
# ### Feature selection

# %%
X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = worst_xgb.partition()
worst_xgb.rfecv_selection("xgb", X_combined, y_combined, X_test, y_test, pds, epsilon, repeats = 100, var = "RR")
# Out:
# Optimal number of features for RR and xgb: 5
# Selected features: ['rr_lag_3', 'rr_lag_1', 'ndvi_lag_4', 'nino34ssta_lag_4', 'precip_total_lag_4']
# New NRMSE with selected features: 3.5907

# %% [markdown]
# # HRF

# %% [markdown]
# ## Fit models

# %%
cod_cant_hrf = []
best_th_hrf = []

# %%
for canton in cantons[0:10]: 
    instancia = Model(df, canton)
    X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = instancia.partition()
    best_th_temp = instancia.hybrid("hrf", X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon)
    cod_cant_hrf.append(canton)
    best_th_hrf.append(best_th_temp)
# Out:
# Using PredefinedSplit: n_train=149, n_val=52
# hrf ready for 101
# Using PredefinedSplit: n_train=32, n_val=37
# hrf ready for 102
# Using PredefinedSplit: n_train=71, n_val=52
# hrf ready for 103
# Using PredefinedSplit: n_train=41, n_val=41
# hrf ready for 104
# Using PredefinedSplit: n_train=11, n_val=1
# hrf ready for 105
# Using PredefinedSplit: n_train=32, n_val=43
# hrf ready for 106
# Using PredefinedSplit: n_train=49, n_val=48
# hrf ready for 107
# Using PredefinedSplit: n_train=39, n_val=35
# hrf ready for 108
# Using PredefinedSplit: n_train=92, n_val=52
# hrf ready for 109
# Using PredefinedSplit: n_train=54, n_val=52
# hrf ready for 110

# %%
for canton in cantons[10:16]: 
    instancia = Model(df, canton)
    X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = instancia.partition()
    best_th_temp = instancia.hybrid("hrf", X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon)
    cod_cant_hrf.append(canton)
    best_th_hrf.append(best_th_temp)
# Out:
# Using PredefinedSplit: n_train=24, n_val=17
# hrf ready for 111
# Using PredefinedSplit: n_train=25, n_val=22
# hrf ready for 112
# Using PredefinedSplit: n_train=51, n_val=45
# hrf ready for 113
# Using PredefinedSplit: n_train=27, n_val=19
# hrf ready for 114
# Using PredefinedSplit: n_train=33, n_val=32
# hrf ready for 115
# Using PredefinedSplit: n_train=28, n_val=16
# hrf ready for 116

# %%
# important: gridsearch was not skipped in 117, the code was changed
instancia = Model(df, "117")
X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = instancia.partition()
best_th_temp = instancia.hybrid("hrf", X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon)
cod_cant_hrf.append("117")
best_th_hrf.append(best_th_temp)
# Out:
# No positive validation observations after filtering. Skipping hyperparameter tuning.
# hrf ready for 117

# %%
for canton in cantons[17:20]: 
    instancia = Model(df, canton)
    X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = instancia.partition()
    best_th_temp = instancia.hybrid("hrf", X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon)
    cod_cant_hrf.append(canton)
    best_th_hrf.append(best_th_temp)
# Out:
# Using PredefinedSplit: n_train=34, n_val=41
# hrf ready for 118
# Using PredefinedSplit: n_train=148, n_val=45
# hrf ready for 119
# Using PredefinedSplit: n_train=7, n_val=3
# hrf ready for 120

# %%
for canton in cantons[20:30]: 
    instancia = Model(df, canton)
    X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = instancia.partition()
    best_th_temp = instancia.hybrid("hrf", X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon)
    cod_cant_hrf.append(canton)
    best_th_hrf.append(best_th_temp)
# Out:
# Using PredefinedSplit: n_train=151, n_val=52
# hrf ready for 201
# Using PredefinedSplit: n_train=39, n_val=38
# hrf ready for -202
# Using PredefinedSplit: n_train=58, n_val=50
# hrf ready for 203
# Using PredefinedSplit: n_train=41, n_val=29
# hrf ready for 204
# Using PredefinedSplit: n_train=99, n_val=52
# hrf ready for 205
# Using PredefinedSplit: n_train=56, n_val=26
# hrf ready for 206
# Using PredefinedSplit: n_train=21, n_val=49
# hrf ready for 207
# Using PredefinedSplit: n_train=58, n_val=40
# hrf ready for 208
# Using PredefinedSplit: n_train=121, n_val=44
# hrf ready for 209
# Using PredefinedSplit: n_train=198, n_val=52
# hrf ready for 210

# %%
for canton in cantons[30:40]: 
    instancia = Model(df, canton)
    X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = instancia.partition()
    best_th_temp = instancia.hybrid("hrf", X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon)
    cod_cant_hrf.append(canton)
    best_th_hrf.append(best_th_temp)
# Out:
# Using PredefinedSplit: n_train=4, n_val=1
# hrf ready for 211
# Using PredefinedSplit: n_train=17, n_val=27
# hrf ready for 212
# Using PredefinedSplit: n_train=41, n_val=17
# hrf ready for 213
# Using PredefinedSplit: n_train=93, n_val=39
# hrf ready for 214
# Using PredefinedSplit: n_train=24, n_val=18
# hrf ready for 215
# Using PredefinedSplit: n_train=82, n_val=48
# hrf ready for 216
# Using PredefinedSplit: n_train=37, n_val=27
# hrf ready for 301
# Using PredefinedSplit: n_train=22, n_val=30
# hrf ready for 302
# Using PredefinedSplit: n_train=47, n_val=38
# hrf ready for 303
# Using PredefinedSplit: n_train=122, n_val=49
# hrf ready for 304

# %%
for canton in cantons[40:50]: 
    instancia = Model(df, canton)
    X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = instancia.partition()
    best_th_temp = instancia.hybrid("hrf", X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon)
    cod_cant_hrf.append(canton)
    best_th_hrf.append(best_th_temp)
# Out:
# Using PredefinedSplit: n_train=167, n_val=52
# hrf ready for 305
# Using PredefinedSplit: n_train=9, n_val=3
# hrf ready for 306
# Using PredefinedSplit: n_train=8, n_val=9
# hrf ready for 307
# Using PredefinedSplit: n_train=21, n_val=19
# hrf ready for 308
# Using PredefinedSplit: n_train=49, n_val=39
# hrf ready for 401
# Using PredefinedSplit: n_train=29, n_val=22
# hrf ready for 402
# Using PredefinedSplit: n_train=25, n_val=25
# hrf ready for 403
# Using PredefinedSplit: n_train=23, n_val=39
# hrf ready for 404
# Using PredefinedSplit: n_train=26, n_val=8
# hrf ready for 405
# Using PredefinedSplit: n_train=12, n_val=8
# hrf ready for 406

# %%
for canton in cantons[50:60]: 
    instancia = Model(df, canton)
    X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = instancia.partition()
    best_th_temp = instancia.hybrid("hrf", X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon)
    cod_cant_hrf.append(canton)
    best_th_hrf.append(best_th_temp)
# Out:
# Using PredefinedSplit: n_train=30, n_val=40
# hrf ready for 407
# Using PredefinedSplit: n_train=36, n_val=36
# hrf ready for 408
# Using PredefinedSplit: n_train=23, n_val=24
# hrf ready for 409
# Using PredefinedSplit: n_train=166, n_val=52
# hrf ready for 410
# Using PredefinedSplit: n_train=35, n_val=34
# hrf ready for 501
# Using PredefinedSplit: n_train=71, n_val=42
# hrf ready for 502
# Using PredefinedSplit: n_train=102, n_val=49
# hrf ready for 503
# Using PredefinedSplit: n_train=64, n_val=25
# hrf ready for 504
# Using PredefinedSplit: n_train=87, n_val=39
# hrf ready for 505
# Using PredefinedSplit: n_train=67, n_val=42
# hrf ready for 506

# %%
for canton in cantons[60:70]: 
    instancia = Model(df, canton)
    X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = instancia.partition()
    best_th_temp = instancia.hybrid("hrf", X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon)
    cod_cant_hrf.append(canton)
    best_th_hrf.append(best_th_temp)
# Out:
# Using PredefinedSplit: n_train=56, n_val=38
# hrf ready for 507
# Using PredefinedSplit: n_train=33, n_val=32
# hrf ready for 508
# Using PredefinedSplit: n_train=30, n_val=17
# hrf ready for 509
# Using PredefinedSplit: n_train=47, n_val=39
# hrf ready for 510
# Using PredefinedSplit: n_train=33, n_val=8
# hrf ready for 511
# Using PredefinedSplit: n_train=176, n_val=52
# hrf ready for 601
# Using PredefinedSplit: n_train=97, n_val=48
# hrf ready for 602
# Using PredefinedSplit: n_train=92, n_val=49
# hrf ready for 603
# Using PredefinedSplit: n_train=42, n_val=41
# hrf ready for 604
# Using PredefinedSplit: n_train=79, n_val=46
# hrf ready for 605

# %%
for canton in cantons[70:82]: 
    instancia = Model(df, canton)
    X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = instancia.partition()
    best_th_temp = instancia.hybrid("hrf", X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon)
    cod_cant_hrf.append(canton)
    best_th_hrf.append(best_th_temp)
# Out:
# Using PredefinedSplit: n_train=82, n_val=38
# hrf ready for 606
# Using PredefinedSplit: n_train=66, n_val=46
# hrf ready for 607
# Using PredefinedSplit: n_train=20, n_val=17
# hrf ready for 608
# Using PredefinedSplit: n_train=84, n_val=33
# hrf ready for 609
# Using PredefinedSplit: n_train=125, n_val=50
# hrf ready for 610
# Using PredefinedSplit: n_train=65, n_val=43
# hrf ready for 611
# Using PredefinedSplit: n_train=161, n_val=42
# hrf ready for 701
# Using PredefinedSplit: n_train=193, n_val=49
# hrf ready for 702
# Using PredefinedSplit: n_train=181, n_val=48
# hrf ready for 703
# Using PredefinedSplit: n_train=194, n_val=39
# hrf ready for 704
# Using PredefinedSplit: n_train=147, n_val=45
# hrf ready for 705
# Using PredefinedSplit: n_train=193, n_val=48
# hrf ready for 706

# %%
# cod_cant_hrf = []
# cod_cant_hrf.append("117")
# for canton in cantons[17:82]: 
#    cod_cant_hrf.append(canton)
# for canton in cantons[0:16]: 
#    cod_cant_hrf.append(canton)

# cod_cant_hrf = [str(x) for x in cod_cant_hrf]

# %%
best_th_hrf_df = pd.DataFrame({"canton": cod_cant_hrf, "best_th": best_th_hrf})

best_th_hrf_df.to_csv("../../data/model_results/thresholds/thresholds_hrf.csv", index = False)

# %% [markdown]
# ## Save metrics

# %%
cod_cant_hrf = []
nrmse_hrf = []

for canton in cantons: 
    instancia = Model(df, canton)
    cant_temp, nrmse_temp = instancia.calculate_nrmse("hrf", epsilon)
    cod_cant_hrf.append(canton)
    nrmse_hrf.append(nrmse_temp)

nrmse_hrf = pd.DataFrame({"canton": cod_cant_hrf,
                         "nrmse": nrmse_hrf})

nrmse_hrf.to_csv("../../data/model_results/metrics/hrf.csv")

# %% [markdown]
# ## Best

# %%
nrmse_hrf = pd.read_csv("../../data/model_results/metrics/hrf.csv")

nrmse_hrf = nrmse_hrf[np.isfinite(nrmse_hrf)] # Prevent using cantons with an NRMSE undefined because their mean cases is 0
nrmse_hrf = nrmse_hrf[nrmse_hrf["nrmse"].notnull()] # Prevent using cantons with an NRMSE undefined because their mean cases is 0

# %%
best_hrf = Model(df, cantons[nrmse_hrf["nrmse"].idxmin()])

# %% [markdown]
# ### Plot results

# %%
X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = best_hrf.partition()
y_pred_point, lower_bound, upper_bound = best_hrf.prediction_intervals(X_combined, y_combined, X_test, epsilon, "hrf", repeats = 100)
best_hrf.serie_temp_canton("hrf", y_pred_point, lower_bound, upper_bound)

# %% [markdown]
# ### Confidence intervals for NRMSE

# %%
print(f"Best canton NRMSE for HRF: {round(nrmse_hrf.iloc[nrmse_hrf["nrmse"].idxmin(), 2], 4)}")
# Out:
# Best canton NRMSE for HRF: 0.3273

# %%
X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = best_hrf.partition()
best_hrf.confint_nrmse("hrf", X_combined, y_combined, X_test, y_test, epsilon, n_bootstraps = 100)
# Out:
# point estimate: 0.41
# lower bound: 0.3, upper bound: 0.8

# %% [markdown]
# ### Feature importance

# %%
X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = best_hrf.partition()
best_hrf.var_importance(X_combined, y_combined, X_test, y_test, "hrf", epsilon, repeats = 100, var = "RR")
# Out:
#                  Feature   imp_hrf   std_hrf
# 0               rr_lag_1  0.024308  0.011824
# 1               rr_lag_2  0.009275  0.014864
# 2               rr_lag_3  0.000994  0.000759
# 3       nino34ssta_lag_4  0.000313  0.000503
# 4       vacaciones_lag_4  0.000222  0.000105
# ..                   ...       ...       ...
# 101     precip_max_lag_3 -0.000056  0.000524
# 102      temp_prom_lag_1 -0.000085  0.000054
# 103  precip_median_lag_1 -0.000117  0.000096
# 104           ndvi_lag_2 -0.000196  0.000318
# 105     precip_max_lag_1 -0.000201  0.000060
#
# [106 rows x 3 columns]
#                  Feature   imp_hrf   std_hrf
# 0               rr_lag_1  0.024308  0.011824
# 1               rr_lag_2  0.009275  0.014864
# 2               rr_lag_3  0.000994  0.000759
# 3       nino34ssta_lag_4  0.000313  0.000503
# 4       vacaciones_lag_4  0.000222  0.000105
# ..                   ...       ...       ...
# 101     precip_max_lag_3 -0.000056  0.000524
# ...

# %% [markdown]
# ### Feature selection

# %%
X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = best_hrf.partition()
best_hrf.rfecv_selection("hrf", X_combined, y_combined, X_test, y_test, pds,  epsilon, repeats = 100, var = "RR")
# Out:
# Optimal number of features for RR and hrf: 14
# Selected features: ['rr_lag_4', 'rr_lag_3', 'rr_lag_2', 'rr_lag_1', 'ndvi_lag_2', 'tmin_mean_lag_3', 'tmin_mean_lag_2', 'nino34ssta_lag_4', 'nino34ssta_lag_3', 'nino34ssta_lag_2', 'nino34ssta_lag_1', 'temp_prom_lag_3', 'empleo_lag_3', 'vacaciones_lag_3']
# New NRMSE with selected features: 0.3259

# %% [markdown]
# ## Worst

# %%
nrmse_hrf = pd.read_csv("../../data/model_results/metrics/hrf.csv")

nrmse_hrf = nrmse_hrf[np.isfinite(nrmse_hrf)] # Prevent using cantons with an NRMSE undefined because their mean cases is 0
nrmse_hrf = nrmse_hrf[nrmse_hrf["nrmse"].notnull()] # Prevent using cantons with an NRMSE undefined because their mean cases is 0

# %%
worst_hrf = Model(df, cantons[nrmse_hrf["nrmse"].idxmax()])

# %% [markdown]
# ### Plot results

# %%
X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = worst_hrf.partition()
y_pred_point, lower_bound, upper_bound = worst_hrf.prediction_intervals(X_combined, y_combined, X_test, epsilon, "hrf", repeats = 100)
worst_hrf.serie_temp_canton("hrf", y_pred_point, lower_bound, upper_bound)

# %% [markdown]
# ### Confidence intervals for NRMSE

# %%
print(f"Worst canton NRMSE for HRF: {round(nrmse_hrf.iloc[nrmse_hrf["nrmse"].idxmax(), 2], 4)}")
# Out:
# Worst canton NRMSE for HRF: 5.0954

# %%
X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = worst_hrf.partition()
worst_hrf.confint_nrmse("hrf", X_combined, y_combined, X_test, y_test, epsilon, n_bootstraps = 100)
# Out:
# point estimate: 4.34
# lower bound: 0.0, upper bound: 17.15

# %% [markdown]
# ### Feature importance

# %%
X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = worst_hrf.partition()
worst_hrf.var_importance(X_combined, y_combined, X_test, y_test, "hrf", epsilon, repeats = 100, var = "RR")
# Out:
#                  Feature   imp_hrf   std_hrf
# 0        temp_prom_lag_2  0.290243  0.161458
# 1           empleo_lag_2  0.217160  0.097583
# 2           fiebre_lag_1  0.217160  0.093007
# 3      precip_mean_lag_3  0.135725  0.129982
# 4             ndvi_lag_1  0.127373  0.144349
# ..                   ...       ...       ...
# 101  precip_median_lag_2  0.000000  0.000000
# 102                urb_0  0.000000  0.000000
# 103     precip_min_lag_3  0.000000  0.000000
# 104      tmax_mean_lag_3 -0.014617  0.177806
# 105         empleo_lag_1 -0.108580  0.123462
#
# [106 rows x 3 columns]
#                  Feature   imp_hrf   std_hrf
# 0        temp_prom_lag_2  0.290243  0.161458
# 1           empleo_lag_2  0.217160  0.097583
# 2           fiebre_lag_1  0.217160  0.093007
# 3      precip_mean_lag_3  0.135725  0.129982
# 4             ndvi_lag_1  0.127373  0.144349
# ..                   ...       ...       ...
# 101  precip_median_lag_2  0.000000  0.000000
# ...

# %% [markdown]
# ### Feature selection

# %%
X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = worst_hrf.partition()
worst_hrf.rfecv_selection("hrf", X_combined, y_combined, X_test, y_test, pds,  epsilon, repeats = 100, var = "RR")
# Out:
# Optimal number of features for RR and hrf: 7
# Selected features: ['ndvi_lag_1', 'tmin_mean_lag_4', 'tmin_mean_lag_3', 'tmin_mean_lag_1', 'aedes_aegypti_lag_1', 'comprar_carro_lag_3', 'precip_median_lag_4']
# New NRMSE with selected features: 6.2405

# %% [markdown]
# # HXGB

# %% [markdown]
# ## Fit models

# %%
cod_cant_hxgb = []
best_th_hxgb = []

# %%
for canton in cantons[0:10]: 
    instancia = Model(df, canton)
    X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = instancia.partition()
    best_th_temp = instancia.hybrid("hxgb", X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon)
    cod_cant_hxgb.append(canton)
    best_th_hxgb.append(best_th_temp)
# Out:
# Using PredefinedSplit: n_train=149, n_val=52
# hxgb ready for 101
# Using PredefinedSplit: n_train=32, n_val=37
# hxgb ready for 102
# Using PredefinedSplit: n_train=71, n_val=52
# hxgb ready for 103
# Using PredefinedSplit: n_train=41, n_val=41
# hxgb ready for 104
# Using PredefinedSplit: n_train=11, n_val=1
# hxgb ready for 105
# Using PredefinedSplit: n_train=32, n_val=43
# hxgb ready for 106
# Using PredefinedSplit: n_train=49, n_val=48
# hxgb ready for 107
# Using PredefinedSplit: n_train=39, n_val=35
# hxgb ready for 108
# Using PredefinedSplit: n_train=92, n_val=52
# hxgb ready for 109
# Using PredefinedSplit: n_train=54, n_val=52
# hxgb ready for 110

# %%
# important: gridsearch was not skipped in 117, the code was changed
for canton in cantons[10:20]: 
    instancia = Model(df, canton)
    X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = instancia.partition()
    best_th_temp = instancia.hybrid("hxgb", X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon)
    cod_cant_hxgb.append(canton)
    best_th_hxgb.append(best_th_temp)
# Out:
# Using PredefinedSplit: n_train=24, n_val=17
# hxgb ready for 111
# Using PredefinedSplit: n_train=25, n_val=22
# hxgb ready for 112
# Using PredefinedSplit: n_train=51, n_val=45
# hxgb ready for 113
# Using PredefinedSplit: n_train=27, n_val=19
# hxgb ready for 114
# Using PredefinedSplit: n_train=33, n_val=32
# hxgb ready for 115
# Using PredefinedSplit: n_train=28, n_val=16
# hxgb ready for 116
# No positive validation observations after filtering. Skipping hyperparameter tuning.
# hxgb ready for 117
# Using PredefinedSplit: n_train=34, n_val=41
# hxgb ready for 118
# Using PredefinedSplit: n_train=148, n_val=45
# hxgb ready for 119
# Using PredefinedSplit: n_train=7, n_val=3
# hxgb ready for 120

# %%
for canton in cantons[20:30]: 
    instancia = Model(df, canton)
    X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = instancia.partition()
    best_th_temp = instancia.hybrid("hxgb", X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon)
    cod_cant_hxgb.append(canton)
    best_th_hxgb.append(best_th_temp)
# Out:
# Using PredefinedSplit: n_train=151, n_val=52
# hxgb ready for 201
# Using PredefinedSplit: n_train=39, n_val=38
# hxgb ready for -202
# Using PredefinedSplit: n_train=58, n_val=50
# hxgb ready for 203
# Using PredefinedSplit: n_train=41, n_val=29
# hxgb ready for 204
# Using PredefinedSplit: n_train=99, n_val=52
# hxgb ready for 205
# Using PredefinedSplit: n_train=56, n_val=26
# hxgb ready for 206
# Using PredefinedSplit: n_train=21, n_val=49
# hxgb ready for 207
# Using PredefinedSplit: n_train=58, n_val=40
# hxgb ready for 208
# Using PredefinedSplit: n_train=121, n_val=44
# hxgb ready for 209
# Using PredefinedSplit: n_train=198, n_val=52
# hxgb ready for 210

# %%
for canton in cantons[30:40]: 
    instancia = Model(df, canton)
    X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = instancia.partition()
    best_th_temp = instancia.hybrid("hxgb", X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon)
    cod_cant_hxgb.append(canton)
    best_th_hxgb.append(best_th_temp)
# Out:
# Using PredefinedSplit: n_train=4, n_val=1
# hxgb ready for 211
# Using PredefinedSplit: n_train=17, n_val=27
# hxgb ready for 212
# Using PredefinedSplit: n_train=41, n_val=17
# hxgb ready for 213
# Using PredefinedSplit: n_train=93, n_val=39
# hxgb ready for 214
# Using PredefinedSplit: n_train=24, n_val=18
# hxgb ready for 215
# Using PredefinedSplit: n_train=82, n_val=48
# hxgb ready for 216
# Using PredefinedSplit: n_train=37, n_val=27
# hxgb ready for 301
# Using PredefinedSplit: n_train=22, n_val=30
# hxgb ready for 302
# Using PredefinedSplit: n_train=47, n_val=38
# hxgb ready for 303
# Using PredefinedSplit: n_train=122, n_val=49
# hxgb ready for 304

# %%
for canton in cantons[40:50]: 
    instancia = Model(df, canton)
    X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = instancia.partition()
    best_th_temp = instancia.hybrid("hxgb", X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon)
    cod_cant_hxgb.append(canton)
    best_th_hxgb.append(best_th_temp)
# Out:
# Using PredefinedSplit: n_train=167, n_val=52
# hxgb ready for 305
# Using PredefinedSplit: n_train=9, n_val=3
# hxgb ready for 306
# Using PredefinedSplit: n_train=8, n_val=9
# hxgb ready for 307
# Using PredefinedSplit: n_train=21, n_val=19
# hxgb ready for 308
# Using PredefinedSplit: n_train=49, n_val=39
# hxgb ready for 401
# Using PredefinedSplit: n_train=29, n_val=22
# hxgb ready for 402
# Using PredefinedSplit: n_train=25, n_val=25
# hxgb ready for 403
# Using PredefinedSplit: n_train=23, n_val=39
# hxgb ready for 404
# Using PredefinedSplit: n_train=26, n_val=8
# hxgb ready for 405
# Using PredefinedSplit: n_train=12, n_val=8
# hxgb ready for 406

# %%
for canton in cantons[50:60]: 
    instancia = Model(df, canton)
    X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = instancia.partition()
    best_th_temp = instancia.hybrid("hxgb", X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon)
    cod_cant_hxgb.append(canton)
    best_th_hxgb.append(best_th_temp)
# Out:
# Using PredefinedSplit: n_train=30, n_val=40
# hxgb ready for 407
# Using PredefinedSplit: n_train=36, n_val=36
# hxgb ready for 408
# Using PredefinedSplit: n_train=23, n_val=24
# hxgb ready for 409
# Using PredefinedSplit: n_train=166, n_val=52
# hxgb ready for 410
# Using PredefinedSplit: n_train=35, n_val=34
# hxgb ready for 501
# Using PredefinedSplit: n_train=71, n_val=42
# hxgb ready for 502
# Using PredefinedSplit: n_train=102, n_val=49
# hxgb ready for 503
# Using PredefinedSplit: n_train=64, n_val=25
# hxgb ready for 504
# Using PredefinedSplit: n_train=87, n_val=39
# hxgb ready for 505
# Using PredefinedSplit: n_train=67, n_val=42
# hxgb ready for 506

# %%
for canton in cantons[60:70]: 
    instancia = Model(df, canton)
    X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = instancia.partition()
    best_th_temp = instancia.hybrid("hxgb", X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon)
    cod_cant_hxgb.append(canton)
    best_th_hxgb.append(best_th_temp)
# Out:
# Using PredefinedSplit: n_train=56, n_val=38
# hxgb ready for 507
# Using PredefinedSplit: n_train=33, n_val=32
# hxgb ready for 508
# Using PredefinedSplit: n_train=30, n_val=17
# hxgb ready for 509
# Using PredefinedSplit: n_train=47, n_val=39
# hxgb ready for 510
# Using PredefinedSplit: n_train=33, n_val=8
# hxgb ready for 511
# Using PredefinedSplit: n_train=176, n_val=52
# hxgb ready for 601
# Using PredefinedSplit: n_train=97, n_val=48
# hxgb ready for 602
# Using PredefinedSplit: n_train=92, n_val=49
# hxgb ready for 603
# Using PredefinedSplit: n_train=42, n_val=41
# hxgb ready for 604
# Using PredefinedSplit: n_train=79, n_val=46
# hxgb ready for 605

# %%
for canton in cantons[70:82]: 
    instancia = Model(df, canton)
    X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = instancia.partition()
    best_th_temp = instancia.hybrid("hxgb", X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon)
    cod_cant_hxgb.append(canton)
    best_th_hxgb.append(best_th_temp)
# Out:
# Using PredefinedSplit: n_train=82, n_val=38
# hxgb ready for 606
# Using PredefinedSplit: n_train=66, n_val=46
# hxgb ready for 607
# Using PredefinedSplit: n_train=20, n_val=17
# hxgb ready for 608
# Using PredefinedSplit: n_train=84, n_val=33
# hxgb ready for 609
# Using PredefinedSplit: n_train=125, n_val=50
# hxgb ready for 610
# Using PredefinedSplit: n_train=65, n_val=43
# hxgb ready for 611
# Using PredefinedSplit: n_train=161, n_val=42
# hxgb ready for 701
# Using PredefinedSplit: n_train=193, n_val=49
# hxgb ready for 702
# Using PredefinedSplit: n_train=181, n_val=48
# hxgb ready for 703
# Using PredefinedSplit: n_train=194, n_val=39
# hxgb ready for 704
# Using PredefinedSplit: n_train=147, n_val=45
# hxgb ready for 705
# Using PredefinedSplit: n_train=193, n_val=48
# hxgb ready for 706

# %%
best_th_hxgb_df = pd.DataFrame({"canton": cod_cant_hxgb,
                         "best_th": best_th_hxgb})

best_th_hxgb_df.to_csv("../../data/model_results/thresholds/thresholds_hxgb.csv")

# %% [markdown]
# ## Save metrics

# %%
cod_cant_hxgb = []
nrmse_hxgb = []

for canton in cantons: 
    instancia = Model(df, canton)
    cant_temp, nrmse_temp = instancia.calculate_nrmse("hxgb", epsilon)
    cod_cant_hxgb.append(canton)
    nrmse_hxgb.append(nrmse_temp)

nrmse_hxgb = pd.DataFrame({"canton": cod_cant_hxgb,
                         "nrmse": nrmse_hxgb})

nrmse_hxgb.to_csv("../../data/model_results/metrics/hxgb.csv")

# %% [markdown]
# ## Best

# %%
nrmse_hxgb = pd.read_csv("../../data/model_results/metrics/hxgb.csv")

nrmse_hxgb = nrmse_hxgb[np.isfinite(nrmse_hxgb)] # Prevent using cantons with an NRMSE undefined because their mean cases is 0
nrmse_hxgb = nrmse_hxgb[nrmse_hxgb["nrmse"].notnull()] # Prevent using cantons with an NRMSE undefined because their mean cases is 0

# %%
best_hxgb = Model(df, cantons[nrmse_hxgb["nrmse"].idxmin()])

# %% [markdown]
# ### Plot results

# %%
X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = best_hxgb.partition()
y_pred_point, lower_bound, upper_bound = best_hxgb.prediction_intervals(X_combined, y_combined, X_test, epsilon, "hxgb", repeats = 100)
best_hxgb.serie_temp_canton("hxgb", y_pred_point, lower_bound, upper_bound)

# %% [markdown]
# ### Confidence intervals for NRMSE

# %%
print(f"Best canton NRMSE for HXGB: {round(nrmse_hxgb.iloc[nrmse_hxgb["nrmse"].idxmin(), 2], 4)}")
# Out:
# Best canton NRMSE for HXGB: 0.0

# %%
X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = best_hxgb.partition()
best_hxgb.confint_nrmse("hxgb", X_combined, y_combined, X_test, y_test, epsilon, n_bootstraps = 100)
# Out:
# point estimate: 6.26
# lower bound: 0.0, upper bound: 18.09

# %% [markdown]
# ### Feature importance

# %%
X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = best_hxgb.partition()
best_hxgb.var_importance(X_combined, y_combined, X_test, y_test, "hxgb", epsilon, repeats = 100, var = "RR")
# Out:
#               Feature  imp_hxgb  std_hxgb
# 0    precip_max_lag_4  0.144197  0.108148
# 1        empleo_lag_4  0.064870  0.118694
# 2    precip_max_lag_3  0.022531  0.067592
# 3          ndvi_lag_3  0.002253  0.022418
# 4            rr_lag_4  0.000000  0.000000
# ..                ...       ...       ...
# 101  precip_min_lag_4  0.000000  0.000000
# 102  precip_min_lag_3  0.000000  0.000000
# 103  precip_min_lag_2  0.000000  0.000000
# 104  precip_min_lag_1  0.000000  0.000000
# 105             urb_0  0.000000  0.000000
#
# [106 rows x 3 columns]
#               Feature  imp_hxgb  std_hxgb
# 0    precip_max_lag_4  0.144197  0.108148
# 1        empleo_lag_4  0.064870  0.118694
# 2    precip_max_lag_3  0.022531  0.067592
# 3          ndvi_lag_3  0.002253  0.022418
# 4            rr_lag_4  0.000000  0.000000
# ..                ...       ...       ...
# 101  precip_min_lag_4  0.000000  0.000000
# 102  precip_min_lag_3  0.000000  0.000000
# 103  precip_min_lag_2  0.000000  0.000000
# ...

# %% [markdown]
# ### Feature selection

# %%
X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = best_hxgb.partition()
best_hxgb.rfecv_selection("hxgb", X_combined, y_combined, X_test, y_test, pds,  epsilon, repeats = 100, var = "RR")
# Out:
# Optimal number of features for RR and hxgb: 14
# Selected features: ['ndvi_lag_4', 'ndvi_lag_3', 'tmax_mean_lag_4', 'tmin_mean_lag_4', 'tmin_mean_lag_1', 'temp_prom_lag_1', 'empleo_lag_4', 'empleo_lag_2', 'empleo_lag_1', 'vacaciones_lag_4', 'precip_total_lag_3', 'precip_total_lag_1', 'precip_max_lag_4', 'precip_max_lag_3']
# New NRMSE with selected features: 0.0000

# %% [markdown]
# ## Worst

# %%
nrmse_hxgb = pd.read_csv("../../data/model_results/metrics/hxgb.csv")

nrmse_hxgb = nrmse_hxgb[np.isfinite(nrmse_hxgb)] # Prevent using cantons with an NRMSE undefined because their mean cases is 0
nrmse_hxgb = nrmse_hxgb[nrmse_hxgb["nrmse"].notnull()] # Prevent using cantons with an NRMSE undefined because their mean cases is 0

# %%
worst_hxgb = Model(df, cantons[nrmse_hxgb["nrmse"].idxmax()])

# %% [markdown]
# ### Plot results

# %%
X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = worst_hxgb.partition()
y_pred_point, lower_bound, upper_bound = worst_hxgb.prediction_intervals(X_combined, y_combined, X_test, epsilon, "hxgb", repeats = 100)
worst_hxgb.serie_temp_canton("hxgb", y_pred_point, lower_bound, upper_bound)

# %% [markdown]
# ### Confidence intervals for NRMSE

# %%
print(f"Worst canton NRMSE for HXGB: {round(nrmse_hxgb.iloc[nrmse_hxgb["nrmse"].idxmax(), 2], 4)}")
# Out:
# Worst canton NRMSE for HXGB: 3.6187

# %%
X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = worst_hxgb.partition()
worst_hxgb.confint_nrmse("hxgb", X_combined, y_combined, X_test, y_test, epsilon, n_bootstraps = 100) # REMEMBER THIS IS INCORRECT
# Out:
# point estimate: 3.79
# lower bound: 3.6, upper bound: 4.77

# %% [markdown]
# ### Feature importance

# %%
X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = worst_hxgb.partition()
worst_hxgb.var_importance(X_combined, y_combined, X_test, y_test, "hxgb", epsilon, repeats = 100, var = "RR")
# Out:
#               Feature  imp_hxgb  std_hxgb
# 0        empleo_lag_3  0.096348  0.096454
# 1            rr_lag_3  0.055334  0.082008
# 2          ndvi_lag_4  0.018165  0.049268
# 3            rr_lag_4  0.007102  0.030957
# 4            rr_lag_1  0.001580  0.015725
# ..                ...       ...       ...
# 101  precip_min_lag_4  0.000000  0.000000
# 102  precip_min_lag_3  0.000000  0.000000
# 103  precip_min_lag_2  0.000000  0.000000
# 104  precip_min_lag_1  0.000000  0.000000
# 105             urb_0  0.000000  0.000000
#
# [106 rows x 3 columns]
#               Feature  imp_hxgb  std_hxgb
# 0        empleo_lag_3  0.096348  0.096454
# 1            rr_lag_3  0.055334  0.082008
# 2          ndvi_lag_4  0.018165  0.049268
# 3            rr_lag_4  0.007102  0.030957
# 4            rr_lag_1  0.001580  0.015725
# ..                ...       ...       ...
# 101  precip_min_lag_4  0.000000  0.000000
# 102  precip_min_lag_3  0.000000  0.000000
# 103  precip_min_lag_2  0.000000  0.000000
# ...

# %% [markdown]
# ### Feature selection

# %%
X_combined, y_combined, X_train, X_test, y_test, test, pds, epsilon = worst_hxgb.partition()
worst_hxgb.rfecv_selection("hxgb", X_combined, y_combined, X_test, y_test, pds,  epsilon, repeats = 100, var = "RR")
# Out:
# Optimal number of features for RR and hxgb: 8
# Selected features: ['rr_lag_3', 'rr_lag_2', 'rr_lag_1', 'tmax_mean_lag_2', 'nino34ssta_lag_4', 'nino34ssta_lag_3', 'dengue_lag_1', 'precip_total_lag_4']
# New NRMSE with selected features: 3.9195
